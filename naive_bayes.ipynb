# %% [markdown]
# # Suggestion engine of UCDs based on common metadata descriptors
#
# Unified Content Descriptors (UCDs) are machine-level descriptions of astronomical data.
# In astronomical data tables, together with columns name, description, and data type, they compose the set of metadata used to describe the content (_i.e._, data) of a dataset.
# Whereas column name and description are free text components -- meaning any set of words of the (english) vocabulary can be used to name and describe the data of columns in a data table --, UCDs compose a minimalist set of words (or _atoms_) arranged under a specific set of rules (grammar, if you will).
# UCDs are one of the results of the semmantics working group of the International Virtual Observatory Alliance (IVOA) used in any of the Virtual Observatory (VO) data resources.
#
# For example, a column of a (VO) catalog (_table_ in astronomical jargon) providing external URL for each of the elements of the table may be called '`access_url`' with a description "`URL used to access (download) dataset`" would have a UCD '`meta.ref.url`' (with a datatype '`string`').
# On one hand, the (english) high-level _description_ of the column -- or even the _name_ -- states clearly to a human what is the content in it. On the other hand, a machine (_i.e._, a software) would have a hard time "understanding" the (human) description. There is where UCDs play their role: properly set, a machine can understand that `meta.ref.url` contains some _meta_ information (non astrophysical quantity) _refering_ to another resource that happens to be an _url_.
#
# The full extent of UCD explanation, vocabulary and grammar, can be seen at http://www.ivoa.net/documents/latest/UCDlist.html and associated documents. In section Data of this document I present other examples of such metadata set.
#
# Although the UCD vocabulary is relatively small and the grammar imposes clear logical rules, data providers (specially newcomers) may have a hard, time-consuming experience in doing it -- much like choosing the keywords for a scientific paper: we know the words but representing the content of the article in a handful of logically conected key-words demands some level of biblioteconomy.
#
# The goal of this note is to apply machine learning (ML) techniques to help the owner of a dataset (_i.e._, catalog) in the process of filling its metadata fields, in particular the UCD field.
# To do so, we will using natural language understanding to clean and normalize the data so that we can feed them to ML algorithms.
# We will a couple of commonly used ML algorithms -- Support Vector Machines (SVM) and Naive Bayes -- to test our predictive hypothesis.
# The data we going to use relate to VO Simple Conesearch Services (SCS), which provide catalogs of astronomical objects (galaxies, stars, planets) of the any, non-specific, content.

# %% [markdown]
# * remove empty column names as well as empty descriptions and respective ucds from the data
# * remove "None" ucds
# * display cleaned versions of column names and descriptions
# * present first 3 results of predictions
# * check if 'truth' value is among the first 3 predicted results

# %%
# The following pipeline was taken from
#https://medium.com/towards-data-science/machine-learning-nlp-text-classification-using-scikit-learn-python-and-nltk-c52b92a7c73a
# a analogous, but more qualitative text is
#https://medium.com/moosend-engineering-data-science/how-to-build-a-machine-learning-industry-classifier-5d19156d692f
#
def read_columns(config,parameter):
    '''
    Return list of 'parameter' from sections in 'config'
    '''
    sections = list(config.keys())
    sections.sort()
    return [ config[s].get(parameter) for s in sections ]


def read_columns_name(config):
    '''
    Return "clean" 'columns' (names) from 'config'
    
    "clean" means clean from '0-9a-zA-Z+-/*.' characters
    '''
    import re
    name_columns = read_columns(config,'columns')
    out = []
    for columns in name_columns:
        blk = []
        for i,column in enumerate(columns):
            clean_column = re.sub('[^0-9a-zA-Z\+\-\/\*\.]',' ',column).strip()
            blk.append(clean_column)
        out.append(blk)
    return out

def read_columns_description(config):
    '''
    Return "clean" 'descriptions' from 'config'
    
    "clean" means clean from '0-9a-zA-Z ' characters
    '''
    import re
    desc_columns = read_columns(config,'descriptions')
    out = []
    nil = []
    for columns in desc_columns:
        blk = []
        for i,column in enumerate(columns):
            try:
                clean_column = re.sub('[^0-9a-zA-Z ]','',column).strip()
#                 clean_column = re.sub(string.punctuation,'',column).strip()
            except:
                nil.append((i,column))
                clean_column = ''
            blk.append(clean_column)
        out.append(blk)
    print("{:d} empty columns".format(len(nil)))
    return out

def read_columns_ucd(config):
    '''
    Return "primary" 'ucds' from 'config'
    
    "primary" means primary ucd words
    '''
    ucd_columns = read_columns(config,'ucds')
    out = []
    for columns in ucd_columns:
        blk = []
        for i,column in enumerate(columns):
            primary_ucd = column.split(';')[0]
            blk.append(primary_ucd)
#             blk.append(column)
        out.append(blk)
    return out

def remove_empty_pairs(ucds, other):
    '''
    Remove ucds/other pairs when 'other' is empty
    '''
    assert len(ucds) == len(other)
    ucds_clean = ucds[:]
    other_clean = other[:]
    empty_ucd_indexes = [i for i,u in enumerate(ucds) if u.lower() == "none" or u.strip() == '']
    print("Number or 'none' UCDs:",len(empty_ucd_indexes))
    empty_other_indexes = [i for i,o in enumerate(other) if o.lower() == "none" or o.strip() == '']
    print("Number or 'none' columns:",len(empty_other_indexes))
    empty_indexes = empty_ucd_indexes + empty_other_indexes
    empty_indexes.sort(reverse=True)
    for i in empty_indexes:
        ucds_clean.pop(i)
        other_clean.pop(i)
    return ucds_clean,other_clean

# %% [markdown]
# ## Data
#
# We are going to use VO conesearch catalogs (SCS) metadata from the [Vizier](https://vizier.u-strasbg.fr/viz-bin/VizieR) laboratory as they provide a curated set of resources.

# %%
with open('data/radio/CATALOGS.json','r') as f:
    import json
    config = json.load(f)

print("The number of catalog metadata sets we are going to use:",len(config))
# Out:
# The number of catalog metadata sets we are going to use: 1367

# %%
print("Example of metadata sets:\n")

# from random import shuffle
# keys = list(config.keys())
# shuffle(keys)

import json
for k in config.keys():
    print(json.dumps(config[k], indent=4))
    break
# Out:
# Example of metadata sets:
#
# {
#     "title": "CSIRO ASKAP Science Data Archive Cone Search Service",
#     "url": "https://casda.csiro.au/casda_vo_tools/scs/obscore?",
#     "ivoid": "ivo://au.csiro/casda/scs",
#     "creators": [
#         "CSIRO"
#     ],
#     "description": "Cone search service for querying catalogues from ASKAP radio astronomy observations",
#     "columns": [
#         "obs_id",
#         "access_url",
#         "target_name",
#         "s_ra",
#         "s_dec"
#     ],
#     "ucds": [
#         "ID_MAIN",
#         "meta.ref.url",
#         "meta.id;src",
#         "POS_EQ_RA_MAIN",
#         "POS_EQ_DEC_MAIN"
#     ],
#     "units": [
#         "None",
#         "None",
#         "None",
#         "deg",
#         "deg"
#     ],
#     "descriptions": [
#         "Observation ID",
#         "URL used to access (download) dataset",
#         "Astronomical object observed, if any",
#         "Central right ascension, ICRS",
#         "Central declination, ICRS"
#     ]
# }

# %%
ucd_columns = read_columns_ucd(config)

# %% [markdown]
# UCDs we have:

# %%
ucd_columns
# Out:
# [['ID_MAIN',
#   'meta.id.assoc',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'phot.flux.density',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'None'],
#  ['meta.id',
#   'None',
#   'phot.flux.density',
#   'stat.error',
#   'meta.id.cross',
#   'ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'src.redshift',
#   'phot.mag',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'src.class',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'stat.error',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'meta.code',
#   'phot.flux.density',
#   'stat.error',
#   'meta.id',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'obs.param',
#   'obs.param',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'meta.id.cross',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'pos.angDistance',
#   'pos.angDistance',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'phys.angSize',
#   'phys.angSize',
#   'None'],
#  ['meta.id',
#   'ID_MAIN',
#   'meta.code',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code',
#   'phot.flux.density',
#   'meta.code',
#   'spect.index',
#   'meta.code',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phys.angSize.smajAxis',
#   'phys.angSize.sminAxis',
#   'pos.posAng',
#   'None'],
#  ['meta.id',
#   'ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'stat.error',
#   'phot.flux.density',
#   'phot.flux.density',
#   'stat.snr',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'stat.error',
#   'em.freq',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.code',
#   'stat.snr',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'meta.code',
#   'phot.flux.density',
#   'meta.code',
#   'phot.flux.density',
#   'meta.code',
#   'phot.flux.density',
#   'meta.code',
#   'phot.flux.density',
#   'meta.code',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'meta.id.cross',
#   'phot.mag',
#   'stat.error',
#   'src.redshift.phot',
#   'stat.error',
#   'src.redshift',
#   'meta.code.qual',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'spect.index',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'meta.id',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'stat.error',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'meta.id',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'src.class',
#   'meta.number',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'phot.flux.density',
#   'stat.error',
#   'phys.angSize.smajAxis',
#   'pos.posAng',
#   'meta.code',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None'],
#  ['ID_MAIN',
#   'meta.id.cross',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'spect.index',
#   'stat.error',
#   'None'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'stat.error',
#   'pos.eq.dec',
#   'stat.error',
#   'phys.angSize',
#   'meta.code',
#   'meta.id.cross',
#   'meta.id',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.code.multip',
#   'em.freq',
#   'instr.bandwidth'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'meta.code',
#   'meta.code',
#   'meta.id',
#   'time.start',
#   'time.epoch',
#   'time.epoch',
#   'time.expo',
#   'instr.setup',
#   'instr.param',
#   'spect.dopplerVeloc',
#   'meta.note',
#   'em.freq',
#   'meta.note',
#   'em.freq',
#   'meta.note',
#   'meta.code',
#   'meta.code',
#   'meta.id',
#   'instr.setup',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'ID_MAIN',
#   'meta.id',
#   'meta.id',
#   'TIME_DATE',
#   'None',
#   'em.freq',
#   'instr.bandwidth',
#   'instr.bandwidth',
#   'instr.setup',
#   'instr.scale',
#   'instr.scale',
#   'meta.number',
#   'meta.code',
#   'meta.id.assoc',
#   'meta.code',
#   'meta.id',
#   'phot.flux.density',
#   'meta.bib',
#   'obs.observer',
#   'meta.note',
#   'meta.id',
#   'meta.ref.url'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.id',
#   'meta.id',
#   'meta.ref',
#   'ID_MAIN',
#   'meta.ref',
#   'pos.eq.ra',
#   'stat.error',
#   'meta.ref',
#   'pos.eq.dec',
#   'stat.error',
#   'meta.ref',
#   'pos.pm',
#   'stat.error',
#   'meta.ref',
#   'pos.pm',
#   'stat.error',
#   'meta.ref',
#   'pos.parallax',
#   'stat.error',
#   'meta.ref',
#   'time.epoch',
#   'meta.ref',
#   'pos.galactic.lon',
#   'pos.galactic.lat',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'time.period',
#   'stat.error',
#   'meta.ref',
#   'arith.rate',
#   'stat.error',
#   'meta.ref',
#   'em.freq',
#   'stat.error',
#   'meta.ref',
#   'em.freq',
#   'stat.error',
#   'meta.ref',
#   'em.freq',
#   'stat.error',
#   'meta.ref',
#   'em.freq',
#   'stat.error',
#   'meta.ref',
#   'time.epoch',
#   'meta.ref',
#   'phys.dispMeasure',
#   'stat.error',
#   'meta.ref',
#   'phys.dispMeasure',
#   'stat.error',
#   'meta.ref',
#   'phys.polarization.rotMeasure',
#   'stat.error',
#   'meta.ref',
#   'src.var.pulse',
#   'stat.error',
#   'meta.ref',
#   'src.var.pulse',
#   'stat.error',
#   'meta.ref',
#   'meta.note',
#   'meta.ref',
#   'time.scale',
#   'stat.error',
#   'meta.ref',
#   'phot.flux.density',
#   'stat.error',
#   'meta.ref',
#   'phot.flux.density',
#   'stat.error',
#   'meta.ref',
#   'phot.flux.density',
#   'stat.error',
#   'meta.ref',
#   'phys.magField',
#   'meta.ref',
#   'time.epoch',
#   'stat.error',
#   'meta.ref',
#   'time.period',
#   'stat.error',
#   'meta.ref',
#   'phys.angSize.smajAxis',
#   'stat.error',
#   'meta.ref',
#   'src.orbital.periastron',
#   'stat.error',
#   'meta.ref',
#   'src.orbital.eccentricity',
#   'stat.error',
#   'meta.ref',
#   'time.epoch',
#   'stat.error',
#   'meta.ref',
#   'stat.param',
#   'stat.error',
#   'meta.ref',
#   'stat.param',
#   'stat.error',
#   'meta.ref',
#   'phys.mass',
#   'phys.mass',
#   'phys.magField',
#   'pos.distance',
#   'pos.distance',
#   'meta.ref',
#   'phys.dispMeasure',
#   'pos.cartesian.z',
#   'pos.cartesian.x',
#   'pos.cartesian.y',
#   'meta.id.assoc',
#   'meta.note',
#   'time.epoch',
#   'meta.code.class',
#   'meta.note',
#   'meta.number',
#   'phys.luminosity',
#   'phys.luminosity',
#   'time.age',
#   'phys.magField',
#   'phys.energy',
#   'phys.energy',
#   'pos.pm',
#   'stat.error',
#   'phys.veloc',
#   'meta.note',
#   'time.age',
#   'phys.magField',
#   'phys.magField',
#   'meta.ref.url'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot',
#   'stat.error',
#   'phot.flux',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'stat.error',
#   'meta.number',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'stat.error',
#   'phys.angSize.smajAxis',
#   'stat.error',
#   'phys.angSize.sminAxis',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'meta.code',
#   'phot.mag',
#   'src.class',
#   'src.redshift',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code',
#   'None'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'time.epoch',
#   'src.var.pulse',
#   'stat.error',
#   'time.period',
#   'arith.rate',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'spect.index',
#   'src.morph.type',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'stat.error',
#   'meta.note',
#   'None'],
#  ['ID_MAIN', 'meta.ref.url', 'meta.id', 'POS_EQ_RA_MAIN', 'POS_EQ_DEC_MAIN'],
#  ['None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'em.freq',
#   'meta.code',
#   'phot.flux.density',
#   'None'],
#  ['ID_MAIN',
#   'meta.id',
#   'meta.code',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'spect.index',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.probability',
#   'pos.angDistance',
#   'phot.mag',
#   'None'],
#  ['meta.ref',
#   'ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'src.redshift',
#   'phot.flux.density',
#   'spect.line.intensity',
#   'phot.mag',
#   'None',
#   'None',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'src.redshift',
#   'phot.flux.density',
#   'spect.line.intensity',
#   'phot.mag',
#   'None',
#   'None',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'stat.error',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'stat.error',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'phot.flux.density',
#   'stat.error',
#   'phys.angSize',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'stat.error',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.qual',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.qual',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'stat.error',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'instr.offset',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'spect.index',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'stat.error',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phys.angSize.smajAxis',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'spect.index',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.qual',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.qual',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code',
#   'spect.index',
#   'stat.error',
#   'stat.error',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.qual',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'stat.error',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'stat.error',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code',
#   'spect.index',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'stat.error',
#   'POS_EQ_DEC_MAIN',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code',
#   'spect.index',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'phot.flux.density',
#   'stat.snr',
#   'phys.angSize',
#   'None'],
#  ['ID_MAIN',
#   'meta.id',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'phot.flux.density',
#   'phot.flux.density',
#   'None'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'src.spType'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.note',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.id'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.id',
#   'ID_MAIN',
#   'meta.id',
#   'meta.code',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.ref.url',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['meta.id',
#   'ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'meta.code',
#   'phot.flux',
#   'stat.error',
#   'src.class',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'time.start',
#   'instr.setup',
#   'instr.setup',
#   'em.freq',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'time.start',
#   'time.duration',
#   'meta.code',
#   'meta.code',
#   'meta.id.PI',
#   'None'],
#  ['ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'time.start',
#   'time.duration',
#   'meta.code',
#   'meta.id.PI',
#   'None'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'meta.id',
#   'pos.eq.ra',
#   'stat.error',
#   'pos.eq.dec',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phys.angSize',
#   'phys.angSize',
#   'pos.posAng',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.galactic.lon',
#   'pos.galactic.lat',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.angDistance',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.error',
#   'phys.angSize',
#   'meta.code.error',
#   'phys.angSize',
#   'meta.code.error',
#   'obs.param',
#   'phot.flux'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.galactic.lon',
#   'pos.galactic.lat',
#   'phot.flux.density',
#   'src.spType',
#   'src.var.index',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['pos.angDistance',
#   'meta.record',
#   'src.class',
#   'ID_MAIN',
#   'src.spType',
#   'meta.code.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.id',
#   'meta.code.error',
#   'spect.index',
#   'stat.error',
#   'meta.code.error',
#   'meta.note',
#   'meta.id',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.id.parent',
#   'ID_MAIN',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'src.redshift',
#   'meta.note',
#   'meta.ref',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'src.class',
#   'ID_MAIN',
#   'meta.code.error',
#   'meta.ref',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.code',
#   'src.spType',
#   'meta.note'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phys.angSize',
#   'phys.angSize',
#   'src.morph.type',
#   'instr.det.noise',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.id.parent',
#   'time.epoch',
#   'meta.code.error',
#   'phot.flux.density',
#   'stat.error',
#   'spect.line.width',
#   'spect.dopplerVeloc',
#   'spect.dopplerVeloc',
#   'spect.dopplerVeloc',
#   'spect.resolution',
#   'phot.flux',
#   'phys.luminosity',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'pos.cartesian.x',
#   'pos.cartesian.y',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.code.error',
#   'phot.antennaTemp',
#   'spect.dopplerVeloc',
#   'spect.line.width',
#   'spect.line.profile',
#   'meta.code.error',
#   'phot.antennaTemp',
#   'spect.dopplerVeloc',
#   'spect.line.width',
#   'spect.line.profile',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.galactic.lon',
#   'pos.galactic.lat',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.code.qual',
#   'meta.code.qual',
#   'meta.code.qual',
#   'meta.code.qual',
#   'phot.color',
#   'phot.color',
#   'phys.temperature',
#   'phot.flux',
#   'stat.error'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.note',
#   'stat.stdev',
#   'phys.temperature',
#   'stat.error',
#   'obs.param',
#   'phys.veloc',
#   'spect.line.width',
#   'phys.veloc',
#   'phys.veloc',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.id',
#   'ID_MAIN',
#   'src.class',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.galactic.lon',
#   'pos.galactic.lat',
#   'pos.distance',
#   'meta.note',
#   'phys.luminosity',
#   'meta.note',
#   'meta.note',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'meta.id',
#   'meta.id',
#   'pos',
#   'pos',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.number',
#   'spect.dopplerVeloc',
#   'phot.antennaTemp',
#   'meta.note',
#   'spect.line.width',
#   'meta.code.error',
#   'meta.code.error',
#   'phot.antennaTemp',
#   'spect.line.width',
#   'meta.code.error',
#   'meta.code.error',
#   'spect.line.intensity',
#   'phys.veloc',
#   'meta.note',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phys.veloc',
#   'instr.det.noise',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.id',
#   'ID_MAIN',
#   'src.morph.type',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phys.veloc',
#   'stat.error',
#   'phot.mag',
#   'phys.angSize',
#   'phot.flux',
#   'phot.flux.density',
#   'stat.error',
#   'phys.veloc',
#   'stat.error',
#   'spect.line.width'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phys.veloc',
#   'phys.veloc',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.note',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.note',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.note',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'src.redshift',
#   'phys.veloc',
#   'pos.distance',
#   'phys.luminosity',
#   'meta.code.error',
#   'phys.mass',
#   'meta.code.error',
#   'None'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'pos.galactic.lon',
#   'pos.galactic.lat',
#   'phys.veloc',
#   'spect.line.width',
#   'pos.distance',
#   'phys.size.radius',
#   'phys.luminosity',
#   'pos.distance',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.id',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'src.morph.type',
#   'meta.id.parent',
#   'spect.dopplerVeloc',
#   'pos.distance',
#   'phys.angSize',
#   'phys.angSize',
#   'phot.mag',
#   'spect.line.width',
#   'time.expo',
#   'instr.det.noise',
#   'meta.code.error',
#   'spect.line.intensity',
#   'stat.error',
#   'spect.dopplerVeloc',
#   'spect.line.width',
#   'meta.code.error',
#   'phys.mass',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.note',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'stat.error',
#   'pos.eq.dec',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'instr.param',
#   'instr.param',
#   'instr.param',
#   'instr.param',
#   'phot.flux.density',
#   'stat.error',
#   'instr.param',
#   'spect.index',
#   'stat.weight',
#   'pos.angResolution',
#   'phys.angSize',
#   'pos.posAng',
#   'meta.note',
#   'pos.posAng',
#   'src.class',
#   'meta.note',
#   'meta.note',
#   'phot.mag',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'meta.id',
#   'pos.galactic.lon',
#   'pos.galactic.lat',
#   'spect.dopplerVeloc',
#   'phys.temperature',
#   'pos.distance',
#   'pos.distance',
#   'phys.size.radius',
#   'spect.line.width',
#   'phys.mass',
#   'phys.mass',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'spect.index',
#   'meta.id',
#   'src.class',
#   'phot.mag',
#   'meta.code.error',
#   'src.redshift',
#   'meta.code.error',
#   'meta.id'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.id',
#   'ID_MAIN',
#   'time.epoch',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'stat.error',
#   'pos.angDistance',
#   'spect.dopplerVeloc',
#   'spect.dopplerVeloc',
#   'phys.veloc',
#   'phys.veloc',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.note',
#   'stat.error',
#   'meta.note',
#   'stat.snr',
#   'meta.id.cross',
#   'meta.id',
#   'stat.fit.goodness'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.code.multip',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.note',
#   'time.epoch',
#   'spect.resolution',
#   'meta.id',
#   'stat.stdev',
#   'spect.dopplerVeloc',
#   'spect.dopplerVeloc',
#   'spect.dopplerVeloc',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.ref',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.note',
#   'ID_MAIN',
#   'meta.code.multip',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.code.error',
#   'phys.polarization.linear',
#   'meta.code',
#   'pos.posAng',
#   'meta.code',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.code',
#   'meta.code.error',
#   'phys.polarization.linear',
#   'meta.code',
#   'pos.posAng',
#   'meta.code',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.code',
#   'meta.code.error',
#   'spect.index',
#   'meta.code',
#   'meta.code.error',
#   'spect.index',
#   'meta.code',
#   'meta.code',
#   'phys.angSize',
#   'phys.angSize',
#   'pos.posAng',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.note',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'obs.field',
#   'phot.flux.density',
#   'phys.angSize',
#   'phot.flux.density',
#   'meta.note',
#   'phot.flux.density',
#   'meta.note',
#   'src.redshift',
#   'meta.code.error',
#   'meta.note',
#   'phys.size',
#   'phys.luminosity',
#   'phys.luminosity',
#   'phys.luminosity',
#   'src.morph.type'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'spect.index',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.ref',
#   'meta.id',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.ref',
#   'phys.angSize',
#   'meta.note',
#   'meta.ref',
#   'meta.code.error',
#   'phys.angSize',
#   'meta.note',
#   'meta.code',
#   'meta.ref',
#   'phys.angSize',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.note',
#   'meta.ref',
#   'meta.number',
#   'meta.number',
#   'pos.posAng',
#   'meta.code.error',
#   'stat.fit.goodness',
#   'stat.error',
#   'meta.code',
#   'time.epoch',
#   'meta.note',
#   'phys.veloc.ang',
#   'stat.error',
#   'meta.note',
#   'stat.fit.chi2',
#   'meta.code.error',
#   'stat.fit.goodness',
#   'stat.error',
#   'meta.note',
#   'stat.fit.chi2',
#   'meta.code.error',
#   'stat.fit.goodness',
#   'stat.error',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.id',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.mag',
#   'meta.code.error',
#   'meta.number',
#   'time.epoch'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'src.class',
#   'meta.number',
#   'phot.flux.density',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.note',
#   'phot.flux.density',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'ID_MAIN',
#   'phot.flux.density',
#   'stat.error',
#   'stat.error',
#   'pos.angDistance',
#   'pos.cartesian',
#   'pos.cartesian',
#   'meta.code',
#   'meta.code',
#   'obs.field'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.number',
#   'phys.veloc',
#   'stat.error',
#   'stat.error',
#   'phys.veloc.dispersion',
#   'stat.error',
#   'stat.error',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.id',
#   'meta.id',
#   'phot.mag',
#   'pos.eq.ra',
#   'stat.error',
#   'pos.eq.dec',
#   'stat.error',
#   'meta.number',
#   'meta.number',
#   'time.epoch'],
#  ['pos.angDistance',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'stat.error',
#   'phys.polarization.stokes',
#   'stat.error',
#   'phys.polarization.stokes',
#   'stat.error',
#   'phys.polarization',
#   'stat.error',
#   'pos.posAng',
#   'stat.error',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phot.flux.density',
#   'spect.index',
#   'phys.luminosity',
#   'src.morph.type',
#   'meta.id.parent',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.mag',
#   'meta.note',
#   'meta.ref',
#   'phys.magAbs',
#   'pos.angDistance',
#   'meta.note',
#   'phys.veloc'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.eq.ra',
#   'pos.eq.ra',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.eq.dec',
#   'pos.eq.dec',
#   'pos.eq.dec',
#   'meta.note',
#   'meta.note',
#   'src.class',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.code.error',
#   'phot.mag',
#   'meta.note',
#   'phot.mag',
#   'phot.mag',
#   'meta.code.error',
#   'src.redshift',
#   'meta.code.error',
#   'meta.ref',
#   'phot.flux.density',
#   'phot.flux.density',
#   'instr.sensitivity',
#   'meta.code',
#   'meta.note',
#   'meta.ref.url',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.id',
#   'src.class',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'spect.dopplerVeloc',
#   'phys.veloc',
#   'phys.veloc',
#   'spect.line.width',
#   'phys.angSize',
#   'phys.angSize',
#   'pos.posAng',
#   'obs.param',
#   'phys.columnDensity',
#   'phot.flux.density',
#   'meta.ref',
#   'meta.ref.url'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'PHOT_FLUX_RADIO_87M',
#   'PHOT_FLUX_RADIO_87M',
#   'OBS_FREQUENCY',
#   'SPECT_SP+INDEX',
#   'SPECT_SP+INDEX',
#   'DATA_LINK',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.id',
#   'ID_MAIN',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.note',
#   'meta.code.class',
#   'meta.id.parent',
#   'meta.ref'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'meta.id',
#   'meta.code.multip',
#   'meta.number',
#   'spect.dopplerVeloc.radio',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phys.angSize',
#   'phys.angSize',
#   'pos.posAng',
#   'meta.ref.url',
#   'meta.ref.url',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.code.multip',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'stat.error',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phys.angSize',
#   'phys.angSize',
#   'pos.posAng'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'DATA_LINK',
#   'NOTE',
#   'PHOT_FLUX_RADIO_1.4G',
#   'ERROR',
#   'CODE_LIMIT',
#   'POL_DEGREE_MISC',
#   'ERROR',
#   'POL_PA_MISC',
#   'ERROR',
#   'PHOT_FLUX_RADIO_2.7G',
#   'ERROR',
#   'PHOT_FLUX_RADIO_2.7G',
#   'ERROR',
#   'CODE_LIMIT',
#   'POL_DEGREE_MISC',
#   'ERROR',
#   'POL_PA_MISC',
#   'ERROR',
#   'PHOT_FLUX_RADIO_5G',
#   'ERROR',
#   'CODE_LIMIT',
#   'POL_DEGREE_MISC',
#   'ERROR',
#   'POL_PA_MISC',
#   'ERROR',
#   'PHOT_FLUX_RADIO_10.7G',
#   'ERROR',
#   'POL_DEGREE_MISC',
#   'ERROR',
#   'POL_PA_MISC',
#   'ERROR',
#   'DATA_LINK',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['pos.angDistance',
#   'meta.record',
#   'meta.note',
#   'ID_MAIN',
#   'meta.code',
#   'src.redshift',
#   'src.class',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.error',
#   'phys.polarization',
#   'stat.error',
#   'spect.index',
#   'spect.index',
#   'phys.luminosity',
#   'meta.code.error',
#   'phys.polarization',
#   'DATA_LINK',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.note',
#   'meta.note',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.angDistance',
#   'src.morph.type',
#   'meta.code.member',
#   'phot.flux.density',
#   'stat.error',
#   'meta.note',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.note',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux',
#   'spect.index',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.id.parent',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phys.absorption',
#   'stat.error',
#   'phot.flux.density',
#   'spect.line.width',
#   'phot.flux.density',
#   'phot.flux.density',
#   'spect.line.width',
#   'phot.flux.density',
#   'phot.flux.density',
#   'spect.line.width',
#   'phot.flux.density',
#   'phot.flux.density',
#   'spect.line.width',
#   'phot.flux.density',
#   'phot.flux.density',
#   'spect.line.width',
#   'phot.flux.density',
#   'phot.flux.density',
#   'spect.line.width',
#   'phot.flux.density',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phys.angSize',
#   'phys.angSize',
#   'pos.posAng',
#   'instr.det.noise'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.code.error',
#   'phys.angSize',
#   'meta.ref',
#   'meta.ref'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'src.class',
#   'phot.mag',
#   'src.redshift',
#   'meta.note',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'pos.distance',
#   'meta.code.error',
#   'phys.angSize',
#   'meta.ref.url',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'NOTE',
#   'ID_ALTERNATIVE',
#   'POS_EQ_RA',
#   'POS_EQ_DEC',
#   'NUMBER',
#   'NUMBER',
#   'NUMBER',
#   'NUMBER'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'RECORD',
#   'ID_MAIN',
#   'ID_ALTERNATIVE',
#   'POS_EQ_RA',
#   'POS_EQ_DEC',
#   'VELOC_HC',
#   'ERROR',
#   'SPECT_LINE_WIDTH',
#   'SPECT_LINE_WIDTH',
#   'ERROR',
#   'SPECT_LINE_WIDTH',
#   'SPECT_LINE_WIDTH',
#   'ERROR',
#   'SPECT_LINE_WIDTH',
#   'NOTE',
#   'SPECT_LINE_WIDTH',
#   'ERROR',
#   'INST_S/N',
#   'CODE_QUALITY',
#   'CODE_MISC',
#   'ID_FILE'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'instr.det.noise',
#   'instr.det.noise',
#   'instr.det.noise',
#   'instr.det.noise',
#   'instr.det.noise',
#   'instr.det.noise',
#   'instr.det.noise',
#   'instr.det.noise',
#   'instr.det.noise',
#   'instr.det.noise',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'spect.line.intensity',
#   'spect.line.intensity',
#   'spect.line.intensity',
#   'meta.note',
#   'meta.note',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'POS_EQ_RA',
#   'POS_EQ_DEC',
#   'POS_GAL_LON',
#   'POS_GAL_LAT',
#   'VELOC_LSR',
#   'VELOC_LSR',
#   'VELOC_LSR',
#   'PHOT_FLUX_RADIO_7.5G',
#   'POS_GAL_GC',
#   'POS_GAL_HC',
#   'POS_GAL_HC',
#   'NOTE',
#   'ID_ALTERNATIVE',
#   'NOTE',
#   'ID_ALTERNATIVE',
#   'ID_ALTERNATIVE',
#   'PHOT_FLUX_RADIO_10.7G',
#   'PHOT_FLUX_RADIO_43G',
#   'PHOT_FLUX_RADIO_90G',
#   'PHOT_FLUX_RADIO_90G',
#   'PHOT_FLUX_RADIO_90G',
#   'PHOT_FLUX_RADIO_125G',
#   'PHOT_FLUX_RADIO_125G',
#   'PHOT_FLUX_RADIO_180G',
#   'REFER_CODE',
#   'DATA_LINK',
#   'DATA_LINK'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.code.error',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'spect.dopplerVeloc',
#   'spect.dopplerVeloc',
#   'meta.code',
#   'meta.code',
#   'meta.code',
#   'pos',
#   'meta.code.error'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.ref.url',
#   'pos.distance',
#   'pos.distance',
#   'meta.note',
#   'phys.luminosity',
#   'phys.luminosity',
#   'phys.luminosity',
#   'phys.luminosity',
#   'phys.luminosity',
#   'phys.luminosity',
#   'meta.note',
#   'phys.luminosity',
#   'phys.luminosity',
#   'meta.note',
#   'pos.galactic.lon',
#   'pos.galactic.lat'],
#  ['pos.angDistance',
#   'meta.record',
#   'src.class',
#   'meta.id.parent',
#   'ID_MAIN',
#   'meta.note',
#   'phys.size.diameter',
#   'phot.flux.density',
#   'stat.error',
#   'meta.note',
#   'meta.code.error',
#   'spect.index',
#   'stat.error',
#   'meta.note',
#   'phot.flux.density',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['pos.angDistance',
#   'RECORD',
#   'ID_MAIN',
#   'SPECT_TYPE_GENERAL',
#   'MORPH_TYPE',
#   'PHYS_DISTANCE_TRUE',
#   'PHYS_LUMINOSITY_HALPHA',
#   'NOTE',
#   'POS_EQ_RA_OTHER',
#   'POS_EQ_DEC_OTHER',
#   'PHOT_FLUX_RADIO_5G',
#   'CODE_LIMIT',
#   'PHOT_FLUX_RADIO_5G',
#   'PHOT_FLUX_RADIO_MISC',
#   'CODE_LIMIT',
#   'PHOT_FLUX_RADIO_15G',
#   'EXTENSION_DIAM',
#   'POS_POS-ANG',
#   'INST_BEAM_SIZE',
#   'INST_BEAM_SIZE',
#   'POS_POS-ANG',
#   'CODE_LIMIT',
#   'PHYS_TEMP_MISC',
#   'PHYS_DISTANCE_TRUE',
#   'NOTE',
#   'DATA_LINK',
#   'DATA_LINK',
#   'DATA_LINK',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'POS_EQ_RA',
#   'POS_EQ_DEC',
#   'PHOT_FLUX_RADIO_87M',
#   'ERROR',
#   'POS_EQ_RA',
#   'POS_EQ_DEC',
#   'PHOT_FLUX_RADIO_87M',
#   'ERROR'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.id.parent',
#   'meta.note',
#   'meta.bib',
#   'phot.flux.density',
#   'phot.fluence',
#   'meta.code.error',
#   'meta.id'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'POS_EQ_RA',
#   'POS_EQ_DEC',
#   'ID_IDENTIFIER',
#   'ID_ALTERNATIVE',
#   'DATA_LINK'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'CLASS_CODE',
#   'TIME_PERIOD',
#   'TIME_DP/DT',
#   'NUMBER',
#   'SPECT_S/N',
#   'VAR_INDEX',
#   'ERROR',
#   'OBS_DETECT-SIGNIF',
#   'TIME_PERIOD',
#   'CODE_ERROR',
#   'ERROR',
#   'ERROR',
#   'TIME_PERIOD',
#   'ERROR',
#   'TIME_PERIOD',
#   'CODE_ERROR',
#   'ERROR',
#   'ERROR',
#   'TIME_PERIOD',
#   'ERROR',
#   'DATA_LINK',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'stat.fit.param',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phys.angSize.smajAxis',
#   'phys.angSize.sminAxis',
#   'stat.error',
#   'meta.id',
#   'meta.id',
#   'meta.id.assoc'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'src.morph.type',
#   'phot.mag',
#   'meta.id.parent',
#   'phys.veloc',
#   'meta.code.error',
#   'phys.mass',
#   'meta.ref',
#   'meta.code.error',
#   'stat.fit.param',
#   'meta.code.qual',
#   'DATA_LINK',
#   'DATA_LINK',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.ref.url',
#   'src.redshift',
#   'src.class',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'spect.index',
#   'phys.magField',
#   'src.morph',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.id',
#   'meta.code.multip',
#   'ID_MAIN',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.code.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.note',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.note',
#   'phot.flux.density',
#   'stat.error'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.galactic.lon',
#   'pos.galactic.lat',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.id.parent',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.note',
#   'pos.eq.ra',
#   'stat.error',
#   'pos.eq.dec',
#   'stat.error',
#   'meta.code',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.error',
#   'phys.angSize',
#   'stat.error',
#   'meta.code.error',
#   'phys.angSize',
#   'stat.error',
#   'pos.posAng',
#   'stat.error',
#   'meta.code.error',
#   'spect.index',
#   'meta.ref.url'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.bib.fig',
#   'ID_MAIN',
#   'meta.code.multip',
#   'pos',
#   'src.morph.param',
#   'instr.filter',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phys.angSize',
#   'phys.angSize.sminAxis',
#   'meta.id',
#   'meta.bib.page',
#   'meta.ref.url',
#   'meta.ref.url',
#   'meta.ref.url',
#   'meta.ref.url'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'stat.error',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phys.angSize',
#   'phys.angSize',
#   'pos.posAng',
#   'meta.note',
#   'meta.id'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'src.redshift',
#   'meta.code.error',
#   'em.freq',
#   'em.freq',
#   'src.var.index',
#   'meta.number',
#   'em.freq',
#   'spect.index',
#   'spect.index',
#   'src.class',
#   'meta.id',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.code.class',
#   'src.var.pulse',
#   'arith.rate',
#   'meta.number',
#   'stat.snr',
#   'src.var.index',
#   'stat.error',
#   'stat.likelihood',
#   'stat.fit.param',
#   'meta.code.error',
#   'stat.error',
#   'stat.error',
#   'stat.fit.param',
#   'stat.error',
#   'stat.fit.param',
#   'meta.code.error',
#   'stat.error',
#   'stat.error',
#   'stat.fit.param',
#   'stat.error',
#   'DATA_LINK',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'stat.error',
#   'pos.eq.dec',
#   'stat.error',
#   'stat.param',
#   'stat.error',
#   'stat.error',
#   'spect.index',
#   'stat.error',
#   'stat.error',
#   'stat.fit.param',
#   'stat.error',
#   'stat.error',
#   'meta.note',
#   'stat.fit.param',
#   'stat.error',
#   'meta.note',
#   'stat.error',
#   'stat.fit.chi2',
#   'src.class'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.id',
#   'meta.ref.url'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.id',
#   'meta.bib.page',
#   'meta.ref.url'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phot.flux.density',
#   'stat.error',
#   'spect.index',
#   'spect.index',
#   'meta.code.class'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'instr.tel',
#   'stat.stdev',
#   'meta.code.multip',
#   'meta.code',
#   'phys.veloc',
#   'phot.antennaTemp',
#   'spect.line.width',
#   'phot.flux',
#   'meta.note',
#   'pos.distance',
#   'pos.distance',
#   'stat.error',
#   'pos.distance',
#   'stat.error',
#   'meta.note',
#   'meta.id',
#   'meta.ref.url',
#   'meta.ref.url'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'phys.mass',
#   'phys.size.radius',
#   'phys.magField',
#   'em.freq',
#   'em.freq',
#   'phot.flux.density',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.code',
#   'meta.id.assoc',
#   'meta.id',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.id',
#   'ID_MAIN',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.code.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.error',
#   'stat.snr',
#   'meta.code.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.error',
#   'stat.snr',
#   'meta.code.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.error',
#   'stat.snr',
#   'meta.code.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.error',
#   'stat.snr',
#   'stat.fit.param',
#   'stat.error',
#   'phys.temperature',
#   'stat.error',
#   'stat.fit.chi2',
#   'stat.fit.param',
#   'stat.error',
#   'phys.temperature',
#   'stat.error',
#   'meta.id',
#   'meta.note',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.id'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.id',
#   'meta.id',
#   'meta.id',
#   'meta.id',
#   'meta.id',
#   'meta.ref.url',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.code.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.ref',
#   'meta.code.error',
#   'phys.luminosity',
#   'meta.code.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.ref',
#   'meta.code.error',
#   'phys.luminosity',
#   'meta.code.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.ref',
#   'meta.code.error',
#   'phys.luminosity',
#   'meta.ref.url',
#   'meta.ref.url',
#   'DATA_LINK',
#   'DATA_LINK',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'spect.index',
#   'stat.error',
#   'spect.index',
#   'stat.error',
#   'em.freq',
#   'meta.id',
#   'meta.ref.url',
#   'meta.code.error',
#   'src.redshift',
#   'meta.code',
#   'src.class',
#   'meta.note',
#   'meta.bib',
#   'meta.note',
#   'em.freq',
#   'phot.flux.density',
#   'meta.note',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.code.error',
#   'phot.flux.density',
#   'src.morph.type'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.record',
#   'meta.id',
#   'meta.note',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phys.angSize',
#   'phys.angSize',
#   'pos.angDistance',
#   'pos.angDistance',
#   'phys.veloc.transverse',
#   'pos.posAng',
#   'meta.code.error'],
#  ['pos.angDistance',
#   'meta.record',
#   'meta.id',
#   'ID_MAIN',
#   'src.redshift',
#   'meta.note',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.note',
#   'ID_MAIN',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.ref',
#   'spect.index',
#   'phot.mag',
#   'meta.note',
#   'phot.mag',
#   'meta.note',
#   'phot.flux.density',
#   'meta.note',
#   'phot.flux.density',
#   'meta.note',
#   'phot.flux.density',
#   'meta.note',
#   'meta.code.error',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.note',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.note',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.note',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.note',
#   'meta.id'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phys.veloc',
#   'em.freq',
#   'meta.id',
#   'meta.id'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.code',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.code.error',
#   'phot.flux.density',
#   'stat.error',
#   'spect.index',
#   'stat.error',
#   'spect.index',
#   'stat.error',
#   'spect.index',
#   'stat.error',
# ...
#   'meta.code',
#   'src.class.struct',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'stat.error',
#   'phot.flux.density',
#   'spect.index',
#   'meta.note',
#   'phot.mag',
#   'src.redshift',
#   'meta.code',
#   'meta.ref',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.note',
#   'phot.flux.density',
#   'phys.angSize',
#   'stat.error',
#   'stat.error',
#   'meta.note',
#   'phot.flux.density',
#   'stat.error',
#   'stat.error',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.id.cross',
#   'src.redshift',
#   'spect.index',
#   'pos.galactic.lon',
#   'pos.galactic.lat',
#   'phot.flux.density',
#   'meta.number',
#   'meta.code',
#   'meta.code',
#   'phot.flux.density',
#   'meta.number',
#   'meta.code',
#   'meta.code',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.ref',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.code.class',
#   'phot.flux.density',
#   'meta.id',
#   'meta.ref.url'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.code.error',
#   'phot.flux.density',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.note',
#   'src.class.struct',
#   'phys.angSize',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'phot.flux.density',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.code.error',
#   'spect.index',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'meta.note',
#   'phot.flux.density',
#   'stat.error',
#   'meta.note',
#   'spect.index',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.note',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.note',
#   'instr.param',
#   'stat.snr',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.code.multip',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phot.flux.density',
#   'stat.snr',
#   'phys.angSize',
#   'meta.number',
#   'meta.number',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phot.flux.density',
#   'stat.snr',
#   'phys.angSize',
#   'meta.number'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'src.spType',
#   'pos.angDistance',
#   'meta.note',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.mag',
#   'meta.note',
#   'src.morph.type',
#   'phys.veloc',
#   'meta.note',
#   'meta.note'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phys.angSize',
#   'meta.code.error',
#   'phys.size.radius',
#   'phys.veloc',
#   'meta.code.error',
#   'phys.veloc.expansion',
#   'meta.code.error',
#   'time.age',
#   'phys.luminosity'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.galactic.lon',
#   'pos.galactic.lat',
#   'phot.flux.density',
#   'phot.flux.density',
#   'stat.snr',
#   'phys.angSize',
#   'meta.number',
#   'meta.note'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'meta.id',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phys.angSize',
#   'phys.angSize',
#   'pos.posAng',
#   'phot.flux.density',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.mag',
#   'phot.mag',
#   'phot.mag',
#   'phot.mag',
#   'phot.mag',
#   'src.class',
#   'meta.code.qual',
#   'pos.angDistance',
#   'src.redshift',
#   'meta.code.qual',
#   'src.spType',
#   'obs.field'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phot.flux.density',
#   'stat.snr',
#   'phys.angSize',
#   'meta.number'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.record',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.note',
#   'arith.factor',
#   'stat.snr',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['pos.angDistance',
#   'meta.record',
#   'meta.ref.url',
#   'ID_MAIN',
#   'meta.code.multip',
#   'meta.id',
#   'meta.code',
#   'phys.polarization.linear',
#   'phys.polarization.circular',
#   'phys.polarization.circular',
#   'phys.polarization.linear',
#   'phys.polarization.circular',
#   'phys.polarization.circular',
#   'phys.polarization.linear',
#   'phys.polarization.circular',
#   'phys.polarization.circular',
#   'phys.polarization.linear',
#   'phys.polarization.circular',
#   'phys.polarization.circular',
#   'phys.polarization.linear',
#   'phys.polarization.circular',
#   'phys.polarization.circular',
#   'phys.polarization.linear',
#   'phys.polarization.circular',
#   'phys.polarization.circular',
#   'spect.line.width',
#   'spect.line.width',
#   'spect.line.eqWidth',
#   'spect.line.width',
#   'spect.line.width',
#   'spect.line.eqWidth',
#   'spect.line.width',
#   'spect.line.width',
#   'spect.line.eqWidth',
#   'spect.line.width',
#   'spect.line.width',
#   'spect.line.eqWidth',
#   'spect.line.width',
#   'spect.line.width',
#   'spect.line.eqWidth',
#   'spect.line.width',
#   'spect.line.width',
#   'spect.line.eqWidth',
#   'meta.id',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.code.multip',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'stat.error',
#   'stat.error',
#   'phys.angSize',
#   'phys.angSize',
#   'pos.posAng',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'pos.cartesian.x',
#   'pos.cartesian.y',
#   'stat.fit.param',
#   'stat.snr',
#   'instr.offset',
#   'meta.id',
#   'meta.id'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.code.multip',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'stat.error',
#   'stat.error',
#   'phys.angSize',
#   'phys.angSize',
#   'pos.posAng',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.error',
#   'stat.snr',
#   'meta.note'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.id',
#   'meta.note',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos',
#   'phot.mag',
#   'phot.color',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.note',
#   'meta.code',
#   'phot.flux.density',
#   'meta.note',
#   'meta.code',
#   'phot.flux.density',
#   'meta.code.error',
#   'phys.angSize',
#   'meta.note',
#   'meta.code',
#   'src.class',
#   'meta.note',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'obs.field',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.ref',
#   'meta.code.error',
#   'meta.ref',
#   'src.class',
#   'src.redshift',
#   'phot.flux.density',
#   'stat.fit.goodness',
#   'meta.number',
#   'meta.code.error',
#   'meta.code.error',
#   'src.var',
#   'phot.flux.density',
#   'phot.flux.density',
#   'spect.index',
#   'meta.note',
#   'spect.index',
#   'meta.note',
#   'meta.code.class',
#   'pos.eq.ra',
#   'pos.eq.dec'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.number',
#   'phot.flux.density',
#   'src.var.index',
#   'pos.posAng',
#   'meta.number',
#   'phot.flux.density',
#   'src.var.index',
#   'pos.posAng',
#   'meta.number',
#   'phot.flux.density',
#   'src.var.index',
#   'pos.posAng',
#   'meta.number',
#   'phot.flux.density',
#   'src.var.index',
#   'pos.posAng',
#   'meta.number',
#   'phot.flux.density',
#   'src.var.index',
#   'pos.posAng',
#   'meta.number',
#   'phot.flux.density',
#   'src.var.index',
#   'pos.posAng',
#   'meta.number',
#   'phot.flux.density',
#   'src.var.index',
#   'pos.posAng',
#   'meta.number',
#   'phot.flux.density',
#   'src.var.index',
#   'pos.posAng',
#   'meta.id',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.mag',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.code.error',
#   'phot.flux.density',
#   'spect.index',
#   'meta.code.error',
#   'spect.index',
#   'meta.code.error',
#   'spect.index'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'POS_EQ_RA',
#   'ERROR',
#   'POS_EQ_DEC',
#   'ERROR',
#   'POS_GAL_LON',
#   'POS_GAL_LAT',
#   'INST_BEAM_MISC',
#   'POS_ANG_DIST_REL',
#   'INST_S/N',
#   'PHOT_FLUX_RADIO_1.4G',
#   'ERROR',
#   'VAR_PULSE_WIDTH',
#   'VAR_PULSE_WIDTH',
#   'TIME_PERIOD',
#   'ERROR',
#   'ORBIT_PERIOD_DERIVATIVE',
#   'ERROR',
#   'TIME_EPOCH',
#   'NUMBER',
#   'TIME_DATE',
#   'TIME_DATE',
#   'FIT_RESIDUAL',
#   'PHYS_DISP-MEASURE',
#   'ERROR',
#   'CODE_LIMIT',
#   'TIME_AGE',
#   'CODE_LIMIT',
#   'PHYS_MAG-FIELD',
#   'CODE_LIMIT',
#   'PHYS_ENERGY_LOSS-RATE',
#   'CODE_LIMIT',
#   'POS_GAL_HC',
#   'CODE_LIMIT',
#   'POS_GAL_Z',
#   'CODE_LIMIT',
#   'PHYS_LUMINOSITY_RADIO',
#   'DATA_LINK'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.id',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'stat.error',
#   'pos.eq.dec',
#   'stat.error',
#   'meta.bib',
#   'pos.eq.ra',
#   'stat.error',
#   'pos.eq.dec',
#   'stat.error',
#   'time.epoch',
#   'time.epoch'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.code.error',
#   'phot.flux.density',
#   'meta.note',
#   'phot.flux.density',
#   'pos.angDistance',
#   'meta.note'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'meta.note',
#   'em.freq',
#   'phot.flux.density'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'NOTE',
#   'POS_EQ_RA',
#   'ERROR',
#   'POS_EQ_DEC',
#   'ERROR',
#   'POS_GAL_LON',
#   'POS_GAL_LAT',
#   'ID_NUMBER',
#   'POS_ANG_DIST_GENERAL',
#   'INST_S/N',
#   'PHOT_FLUX_RADIO_1.4G',
#   'ERROR',
#   'VAR_PULSE_EQ-WIDTH',
#   'VAR_PULSE_EQ-WIDTH',
#   'CODE_MISC',
#   'TIME_PERIOD',
#   'ERROR',
#   'ORBIT_PERIOD_DERIVATIVE',
#   'ERROR',
#   'TIME_EPOCH',
#   'NUMBER',
#   'TIME_DATE',
#   'TIME_DATE',
#   'ERROR',
#   'PHYS_DISP-MEASURE',
#   'ERROR'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'ID_FIELD',
#   'POS_EQ_RA',
#   'POS_EQ_DEC',
#   'PHOT_FLUX_RADIO_36G'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'time.epoch'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.flux.density',
#   'stat.error',
#   'meta.note',
#   'stat.snr',
#   'phot.flux.density',
#   'stat.error'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.code.qual',
#   'stat.likelihood',
#   'meta.note',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.mag',
#   'stat.error',
#   'meta.note',
#   'phot.mag',
#   'stat.error',
#   'meta.note',
#   'phot.mag',
#   'stat.error',
#   'meta.note',
#   'src.class.starGalaxy',
#   'meta.note'],
#  ['pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.code.error',
#   'phot.flux.density',
#   'phot.flux.density',
#   'meta.code.error',
#   'phot.flux',
#   'meta.ref',
#   'meta.ref',
#   'meta.note',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['pos.angDistance',
#   'RECORD',
#   'ID_MAIN',
#   'REDSHIFT_HC',
#   'CODE_LIMIT',
#   'SPECT_EQ-WIDTH',
#   'CODE_LIMIT',
#   'SPECT_LUMINOSITY',
#   'CODE_LIMIT',
#   'SPECT_EQ-WIDTH',
#   'CODE_LIMIT',
#   'SPECT_LUMINOSITY',
#   'CODE_LIMIT',
#   'SPECT_LUMINOSITY',
#   'SPECT_FEATURE_PROP',
#   'ERROR',
#   'DATA_LINK',
#   'DATA_LINK',
#   'POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'meta.code',
#   'pos.eq.ra',
#   'stat.error',
#   'pos.eq.dec',
#   'stat.error',
#   'pos.galactic.lon',
#   'pos.galactic.lat',
#   'meta.id',
#   'pos.angDistance',
#   'stat.snr',
#   'phot.flux.density',
#   'stat.error',
#   'src.var.pulse',
#   'src.var.pulse',
#   'meta.note',
#   'time.period',
#   'stat.error',
#   'meta.note',
#   'stat.error',
#   'time.epoch',
#   'meta.number',
#   'time.epoch',
#   'time.epoch',
#   'stat.fit.residual',
#   'phys.dispMeasure',
#   'stat.error',
#   'time.age',
#   'phys.magField',
#   'phys.energy',
#   'pos.distance',
#   'pos.cartesian.z',
#   'phys.luminosity',
#   'meta.ref.url'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'ID_MAIN',
#   'meta.record',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'phot.count',
#   'meta.note',
#   'stat.error',
#   'phot.flux',
#   'stat.error',
#   'time.duration',
#   'meta.code.error',
#   'stat.value',
#   'meta.id.assoc',
#   'phot.mag',
#   'src.class.starGalaxy',
#   'src.redshift',
#   'meta.code.error',
#   'meta.note',
#   'meta.note'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'meta.ref.url',
#   'ID_MAIN',
#   'meta.code',
#   'meta.note',
#   'meta.id',
#   'pos.eq.ra',
#   'stat.error',
#   'pos.eq.dec',
#   'stat.error',
#   'time.period',
#   'stat.error',
#   'time.period',
#   'stat.error',
#   'em.freq',
#   'stat.error',
#   'phys.dispMeasure',
#   'stat.error',
#   'phys.dispMeasure',
#   'stat.error',
#   'time.epoch',
#   'stat.error',
#   'pos.ecliptic.lon',
#   'stat.error',
#   'pos.ecliptic.lat',
#   'stat.error',
#   'pos.pm',
#   'stat.error',
#   'pos.pm',
#   'stat.error',
#   'pos.pm',
#   'stat.error',
#   'pos.pm',
#   'stat.error',
#   'meta.number',
#   'time.interval',
#   'stat.error',
#   'DATA_LINK'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'NOTE',
#   'POS_EQ_RA',
#   'POS_EQ_DEC',
#   'POS_EQ_RA',
#   'POS_EQ_DEC',
#   'CODE_LIMIT',
#   'PHOT_PHG_BJ',
#   'MORPH_PARAM',
#   'POS_OFFSET',
#   'PHOT_FLUX_RADIO_15G',
#   'ERROR',
#   'PHOT_FLUX_RADIO_5G',
#   'ERROR',
#   'PHOT_FLUX_RADIO_850M',
#   'ERROR',
#   'SPECT_SP+INDEX',
#   'ERROR',
#   'ID_ALTERNATIVE',
#   'NOTE',
#   'DATA_LINK',
#   'DATA_LINK'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'meta.record',
#   'ID_MAIN',
#   'pos.eq.ra',
#   'pos.eq.dec',
#   'src.sample',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phot.flux.density',
#   'stat.error',
#   'phys.angSize',
#   'meta.note',
#   'meta.id',
#   'meta.code.error',
#   'phot.mag',
#   'stat.error',
#   'phys.angSize',
#   'meta.note',
#   'instr.obsty.seeing',
#   'meta.code.error',
#   'phot.color',
#   'meta.note',
#   'src.class',
#   'meta.id'],
#  ['POS_EQ_RA_MAIN',
#   'POS_EQ_DEC_MAIN',
#   'pos.angDistance',
#   'RECORD',
#   'ID_NUMBER',
#   'ID_MAIN',
#   'POS_EQ_RA',
#   'POS_EQ_DEC',
#   'PHOT_FLUX_RADIO_400M',
#   'PHOT_FLUX_RADIO_850M',
#   'PHOT_FLUX_RADIO_850M',
#   'PHOT_FLUX_RADIO_1.4G',
#   'PHOT_FLUX_RADIO_2.7G',
#   'PHOT_FLUX_RADIO_5G',
#   'PHOT_FLUX_RADIO_8.4G',
#   'PHYS_LUMINOSITY_X',
#   'SPECT_SP+INDEX',
#   'ERROR',
#   'PHOT_FLUX_RADIO_1G',
#   'CLASS_OBJECT',
#   'CLASS_OBJECT',
#   'ID_CROSSID',
#   'REMARKS',
#   'ID_PARENT'],
#  ...]

# %% [markdown]
# ## Classifying the column names

# %%
import numpy as np

name_columns = read_columns_name(config)
assert len(name_columns) == len(ucd_columns)

names = [ n for names in name_columns for n in names ]
np.array(names).shape
# Out:
# (24511,)

# %% [markdown]
# Features we have:

# %%
names
# Out:
# ['name',
#  'at20g name',
#  'ra',
#  'dec',
#  'meas flux 148 ghz',
#  'flux 148 ghz',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 148 ghz',
#  'flux 148 ghz neg err',
#  'flux 148 ghz pos err',
#  'flux 218 ghz',
#  'flux 218 ghz neg err',
#  'flux 218 ghz pos err',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'ra error',
#  'dec error',
#  'flux 20 cm',
#  'flux 20 cm error',
#  'int flux 20 cm',
#  'int flux 20 cm error',
#  'Search Offset',
#  'source number',
#  'aegis20 name',
#  'int flux 20 cm',
#  'int flux 20 cm error',
#  'counterpart id',
#  'name',
#  'ra',
#  'dec',
#  'redshift',
#  'irac 3p6 um mag',
#  'irac 3p6 um mag error',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 2 cm',
#  'flux 2 cm error',
#  'int flux 2 cm',
#  'int flux 2 cm error',
#  'source type',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 2 cm',
#  'flux 2 cm error',
#  'centroid ra',
#  'centroid dec',
#  'int flux 2 cm',
#  'int flux 2 cm error',
#  'Search Offset',
#  'name',
#  'ra',
#  'ra error',
#  'dec',
#  'dec error',
#  'flux 863 mhz',
#  'flux 863 mhz error',
#  'int flux 863 mhz',
#  'int flux 863 mhz error',
#  'rms 863 mhz',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 18 ghz',
#  'flux 18 ghz error',
#  'pol flux 18 ghz limit',
#  'pol flux 18 ghz',
#  'pol flux 18 ghz error',
#  'source flags',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 1p5 cm limit',
#  'flux 1p5 cm',
#  'flux 1p5 cm error',
#  'alt name',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 20 ghz',
#  'flux 8p6 ghz',
#  'flux 4p8 ghz',
#  'flux 1p4 ghz',
#  'vis 1',
#  'vis 2',
#  'vis error',
#  'Search Offset',
#  'name',
#  'twofgl name',
#  'ra',
#  'dec',
#  'flux 5 ghz',
#  'flux 5 ghz error',
#  'flux 9 ghz',
#  'flux 9 ghz error',
#  'off set',
#  'norm offset',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 20 cm',
#  'flux 20 cm error',
#  'nvss flux 20 cm',
#  'major axis',
#  'minor axis',
#  'Search Offset',
#  'source number',
#  'name',
#  'source flag',
#  'ra',
#  'dec',
#  'flux 20 cm',
#  'flux 20 cm error',
#  'int flux 20 cm',
#  'int flux 20 cm error',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 20 ghz',
#  'flux 20 ghz error',
#  'flux 1p4 ghz limit',
#  'flux 1p4 ghz',
#  'spectral index limit',
#  'spectral index',
#  'spectral class flag',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 1p4 ghz',
#  'int flux 1p4 ghz',
#  'major axis',
#  'minor axis',
#  'position angle',
#  'Search Offset',
#  'alt name',
#  'name',
#  'ra',
#  'dec',
#  'ra error',
#  'dec error',
#  'flux 1p4 ghz',
#  'int flux 1p4 ghz',
#  'snr 1p4 ghz',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'ra error',
#  'dec error',
#  'frequency',
#  'flux',
#  'int flux',
#  'int flux flag',
#  'snr',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 1p4 ghz limit',
#  'flux 1p4 ghz',
#  'flux 2p5 ghz limit',
#  'flux 2p5 ghz',
#  'flux 5p2 ghz limit',
#  'flux 5p2 ghz',
#  'flux 8p7 ghz limit',
#  'flux 8p7 ghz',
#  'agn flag',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'ctio source number',
#  'vmag',
#  'vmag error',
#  'phot redshift',
#  'phot redshift error',
#  'redshift',
#  'redshift flag',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 2p3 ghz',
#  'flux 2p3 ghz error',
#  'flux 1p4 ghz',
#  'flux 1p4 ghz error',
#  'spectral index',
#  'spectral index error',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 5p5 ghz',
#  'flux 5p5 ghz error',
#  'int flux 5p5 ghz',
#  'rms 5p5 ghz',
#  'Search Offset',
#  'name',
#  'alt name',
#  'ra',
#  'dec',
#  'ra error',
#  'dec error',
#  'flux 1p4 ghz',
#  'rms 1p4 ghz',
#  'int flux 1p4 ghz',
#  'Search Offset',
#  'name',
#  'ra',
#  'ra error',
#  'dec',
#  'dec error',
#  'flux 1p4 ghz',
#  'flux 1p4 ghz error',
#  'int flux 1p4 ghz',
#  'int flux 1p4 ghz error',
#  'Search Offset',
#  'name',
#  'alt name',
#  'ra',
#  'dec',
#  'ra error',
#  'dec error',
#  'flux 1p4 ghz',
#  'flux 1p4 ghz error',
#  'int flux 1p4 ghz',
#  'int flux 1p4 ghz error',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 1p4 ghz',
#  'source type',
#  'number cpts',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 2p1 ghz',
#  'int flux 2p1 ghz',
#  'int flux 2p1 ghz error',
#  'major axis',
#  'position angle',
#  'source flags',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'period',
#  'period error',
#  'period dot',
#  'period dot error',
#  'dm',
#  'dm error',
#  'Search Offset',
#  'name',
#  'pmn name',
#  'ra',
#  'dec',
#  'flux 3p5 cm',
#  'flux 3p5 cm error',
#  'flux 6 cm',
#  'flux 6 cm error',
#  'spectral index',
#  'spectral index error',
#  'Search Offset',
#  'RAJ2000',
#  'DEJ2000',
#  'r',
#  'recno',
#  'Name',
#  'RAJ2000',
#  'e RAs',
#  'DEJ2000',
#  'e DEs',
#  'Beam',
#  'Vpos',
#  'Opt',
#  'WSRT',
#  'Wpeak',
#  'Wint',
#  'm WSRT',
#  'Freq',
#  'FWHM',
#  'RAJ2000',
#  'DEJ2000',
#  'r',
#  'recno',
#  'Nw',
#  'Prog',
#  'Name',
#  'Obs',
#  't1',
#  't2',
#  'tos',
#  'Type',
#  'oEq',
#  'Vel',
#  'n Vel',
#  'Flow',
#  'n Flow',
#  'Fhigh',
#  'n Fhigh',
#  'pol',
#  'p4',
#  'Conf',
#  'Config',
#  'RAJ2000',
#  'DEJ2000',
#  'RAJ2000',
#  'DEJ2000',
#  'r',
#  'recno',
#  'RAJ2000',
#  'DEJ2000',
#  'Name',
#  'Station',
#  'DataID',
#  'begDATE',
#  'endDATE',
#  'Freq',
#  'Chanwidth',
#  'Bandwidth',
#  'Stokes',
#  'pixRA',
#  'pixDE',
#  'Nvisib',
#  'Type',
#  'Assoc',
#  'AssocType',
#  'AMPCAL',
#  'AmpFlux',
#  'PropID',
#  'PIname',
#  'Comments',
#  'DataNo',
#  'MERLIN',
#  'RAJ2000',
#  'DEJ2000',
#  'r',
#  'recno',
#  'Seq',
#  'Name',
#  'r Name',
#  'PSRJ',
#  'r PSRJ',
#  'RAJ2000',
#  'e RAJ2000',
#  'r RAJ2000',
#  'DEJ2000',
#  'e DEJ2000',
#  'r DEJ2000',
#  'pmRA',
#  'e pmRA',
#  'r pmRA',
#  'pmDE',
#  'e pmDE',
#  'r pmDE',
#  'Plx',
#  'e Plx',
#  'r Plx',
#  'PosEp',
#  'r PosEp',
#  'GLON',
#  'GLAT',
#  'RA2000',
#  'DE2000',
#  'P0',
#  'e P0',
#  'r P0',
#  'P1',
#  'e P1',
#  'r P1',
#  'F0',
#  'e F0',
#  'r F0',
#  'F1',
#  'e F1',
#  'r F1',
#  'F2',
#  'e F2',
#  'r F2',
#  'F3',
#  'e F3',
#  'r F3',
#  'PEpoch',
#  'r PEpoch',
#  'DM',
#  'e DM',
#  'r DM',
#  'dDM/dt',
#  'e dDM/dt',
#  'r dDM/dt',
#  'RM',
#  'e RM',
#  'r RM',
#  'W50',
#  'e W50',
#  'r W50',
#  'W10',
#  'e W10',
#  'r W10',
#  'Units',
#  'r Units',
#  'TAUSC',
#  'e TAUSC',
#  'r TAUSC',
#  'S400',
#  'e S400',
#  'r S400',
#  'S1400',
#  'e S1400',
#  'r S1400',
#  'S2000',
#  'e S2000',
#  'r S2000',
#  'Binary',
#  'r Binary',
#  'T0',
#  'e T0',
#  'r T0',
#  'PB',
#  'e PB',
#  'r PB',
#  'A1',
#  'e A1',
#  'r A1',
#  'OM',
#  'e OM',
#  'r OM',
#  'Ecc',
#  'e Ecc',
#  'r Ecc',
#  'TASC',
#  'e TASC',
#  'r TASC',
#  'EPS1',
#  'e EPS1',
#  'r EPS1',
#  'EPS2',
#  'e EPS2',
#  'r EPS2',
#  'minM',
#  'medM',
#  'BINCOMP',
#  'Dist',
#  'DistDM',
#  'r DistDM',
#  'DMsinb',
#  'ZZ',
#  'XX',
#  'YY',
#  'Assoc',
#  'Survey',
#  'Date',
#  'Type',
#  'r Type',
#  'NGlt',
#  'RLUM',
#  'RLUM14',
#  'Age',
#  'Bsurf',
#  'Edot',
#  'Edot2',
#  'PMTot',
#  'e PMTot',
#  'VTrans',
#  'P1I',
#  'Agei',
#  'BSurfi',
#  'BLC',
#  'Simbad',
#  'name',
#  'ra',
#  'dec',
#  'hb count rate',
#  'hb count rate error',
#  'hb flux',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'ra error',
#  'dec error',
#  'flux 153 mhz',
#  'flux 153 mhz error',
#  'rms 153 mhz',
#  'num gaussians',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'error radius',
#  'flux 22 cm',
#  'flux 22 cm error',
#  'rms 22 cm',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'int flux 1420 mhz',
#  'int flux 1420 mhz error',
#  'rms 1420 mhz',
#  'major axis',
#  'major axis error',
#  'minor axis',
#  'minor axis error',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 3p6 cm',
#  'rmag limit',
#  'rmag',
#  'source type',
#  'redshift',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 1p4 ghz',
#  'flux 1p4 ghz error',
#  'int flux 1p4 ghz',
#  'int flux 1p4 ghz error',
#  'multi cpt flag',
#  'Search Offset',
#  'ra',
#  'dec',
#  'mjd',
#  'nu',
#  'nu error',
#  'period',
#  'period dot',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 3p6 cm',
#  'spectral index 2',
#  'morph type',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 20 cm',
#  'flux 6 cm',
#  'flux 3p6 cm',
#  'flux 1 cm',
#  'flux 1 cm error',
#  'notes',
#  'Search Offset',
#  'obs id',
#  'access url',
#  'target name',
#  's ra',
#  's dec',
#  'projid',
#  'date obs',
#  'src name',
#  'coord md',
#  'equinox',
#  'ra angle',
#  'dec angle',
#  'obsfreq',
#  'backend',
#  'frontend',
#  'obs mode',
#  'filename',
#  'collection fedora pid',
#  'observation start time',
#  'obstype',
#  'obs length',
#  'data collection id',
#  'name',
#  'ra',
#  'dec',
#  'frequency',
#  'limit flux radio',
#  'flux radio',
#  'Search Offset',
#  'name',
#  'fermi 2fgl name',
#  'source flag',
#  'ra',
#  'dec',
#  'ra error',
#  'dec error',
#  'flux 5 ghz',
#  'flux 5 ghz error',
#  'spectral index',
#  'spectral index error',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 20 cm',
#  'flux 20 cm error',
#  'int flux 20 cm',
#  'sidelobe prob',
#  'twomass first offset',
#  'twomass kmag',
#  'Search Offset',
#  'galaxy sample',
#  'name',
#  'ra',
#  'dec',
#  'redshift',
#  'nvss flux 1p4 ghz',
#  'o iii flux',
#  'rmag',
#  'log 1p4 ghz luminosity',
#  'log black hole mass',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'redshift',
#  'nvss flux 1p4 ghz',
#  'o iii flux',
#  'rmag',
#  'log 1p4 ghz luminosity',
#  'log black hole mass',
#  'Search Offset',
#  'name',
#  'ra',
#  'ra error',
#  'dec',
#  'dec error',
#  'flux 6 cm',
#  'flux 6 cm error',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 31 ghz',
#  'flux 31 ghz error',
#  'flux 1p4 ghz',
#  'flux 1p4 ghz error',
#  'detection flag',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 91 cm',
#  'flux 91 cm error',
#  'int flux 91 cm',
#  'Search Offset',
#  'name',
#  'ra',
#  'ra error',
#  'dec',
#  'dec error',
#  'flux 151 mhz',
#  'flux 151 mhz error',
#  'int flux 151 mhz',
#  'int flux 151 mhz error',
#  'local rms 151 mhz',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 610 mhz',
#  'int flux 610 mhz',
#  'int flux 610 mhz error',
#  'angular size',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 150 mhz',
#  'flux 150 mhz error',
#  'int flux 150 mhz',
#  'int flux 150 mhz error',
#  'Search Offset',
#  'name',
#  'ra',
#  'ra error',
#  'dec',
#  'dec error',
#  'flux 150 mhz',
#  'flux 150 mhz error',
#  'int flux 150 mhz',
#  'int flux 150 mhz error',
#  'rms 150 mhz',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 610 mhz',
#  'rms 610 mhz',
#  'int flux 610 mhz',
#  'int flux 610 mhz error',
#  'sextractor db flag',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 610 mhz',
#  'rms 610 mhz',
#  'int flux 610 mhz',
#  'int flux 610 mhz error',
#  'sextractor db flag',
#  'Search Offset',
#  'name',
#  'ra',
#  'ra error',
#  'dec',
#  'dec error',
#  'flux 325 mhz',
#  'flux 325 mhz error',
#  'int flux 325 mhz',
#  'int flux 325 mhz error',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'off axis',
#  'flux 153 mhz',
#  'flux 244 mhz',
#  'wenss flux 330 mhz',
#  'flux 610 mhz',
#  'spectral index',
#  'Search Offset',
#  'name',
#  'ra',
#  'ra error',
#  'dec',
#  'dec error',
#  'flux',
#  'flux error',
#  'major axis',
#  'major axis error',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 150 mhz',
#  'wsrt flux 327 mhz',
#  'first flux 1400 mhz',
#  'spectral index',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 610 mhz',
#  'rms 610 mhz',
#  'int flux 610 mhz',
#  'int flux 610 mhz error',
#  'sextractor db flag',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 610 mhz',
#  'rms 610 mhz',
#  'int flux 610 mhz',
#  'int flux 610 mhz error',
#  'sextractor db flag',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 610 mhz',
#  'flux 610 mhz error',
#  'spectral index limit',
#  'spectral index',
#  'spectral index pos err',
#  'spectral index neg err',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 610 mhz',
#  'rms 610 mhz',
#  'int flux 610 mhz',
#  'int flux 610 mhz error',
#  'sextractor db flag',
#  'Search Offset',
#  'name',
#  'ra',
#  'ra error',
#  'dec',
#  'dec error',
#  'flux 610 mhz',
#  'flux 610 mhz error',
#  'int flux 610 mhz',
#  'int flux 610 mhz error',
#  'resolved flag',
#  'Search Offset',
#  'name',
#  'ra',
#  'ra error',
#  'dec',
#  'dec error',
#  'flux 240 mhz',
#  'flux 240 mhz error',
#  'spectral index limit',
#  'spectral index',
#  'Search Offset',
#  'name',
#  'ra',
#  'ra error',
#  'dec',
#  'dec error',
#  'flux 610 mhz',
#  'flux 610 mhz error',
#  'spectral index limit',
#  'spectral index',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'flux 151 mhz',
#  'int flux 151 mhz',
#  'snr',
#  'source extent',
#  'Search Offset',
#  'name',
#  'alt name',
#  'ra',
#  'dec',
#  'flux 2 cm',
#  'flux 3p6 cm',
#  'Search Offset',
#  'RAJ2000',
#  'DEJ2000',
#  'r',
#  'recno',
#  'IAU',
#  'Other',
#  'RAJ2000',
#  'DEJ2000',
#  'TYPE',
#  'RAJ2000',
#  'DEJ2000',
#  'r',
#  'recno',
#  'SFlag',
#  'Name',
#  'RAJ2000',
#  'DEJ2000',
#  'Alias',
#  'RAJ2000',
#  'DEJ2000',
#  'r',
#  'recno',
#  'Seq',
#  'Name',
#  'Alias',
#  'Det',
#  'RA1950',
#  'DE1950',
#  'Data',
#  'RA.icrs',
#  'DE.icrs',
#  'source number',
#  'name',
#  'ra',
#  'dec',
#  'confusion flag',
#  'flux',
#  'flux error',
#  'source type',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'time',
#  'observation mode',
#  'receiver band name',
#  'spectral frequency',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'time',
#  'exposure',
#  'program type',
#  'program code',
#  'pi name',
#  'Search Offset',
#  'name',
#  'ra',
#  'dec',
#  'time',
#  'exposure',
#  'program type',
#  'pi name',
#  'Search Offset',
#  'RAJ2000',
#  'DEJ2000',
#  'r',
#  'recno',
#  'Name',
#  'RA1950',
#  'e RA1950',
#  'DE1950',
#  'e DE1950',
#  'Si',
#  'e Si',
#  'Sp',
#  'e Sp',
#  'MajAxis',
#  'MinAxis',
#  'PA',
#  'RA.icrs',
#  'DE.icrs',
#  'RAJ2000',
#  'DEJ2000',
#  'r',
#  'recno',
#  'IRAS',
#  'GLON',
#  'GLAT',
#  'RA1950',
#  'DE1950',
#  'Dist',
#  'S6cm',
#  'e S6cm',
#  'l FWHM',
#  'FWHM',
#  'l Diam',
#  'Diam',
#  'l Tb',
#  'Tb',
#  'IRE',
#  'RAJ2000',
#  'DEJ2000',
#  'r',
#  'recno',
#  'IRAS',
#  'RA1950',
#  'DE1950',
#  'GLON',
#  'GLAT',
#  'Flux',
#  'LRS',
#  'Var',
#  'Name',
#  'RA.icrs',
#  'DE.icrs',
#  'r',
#  'recno',
#  'St',
#  'Name',
#  'SpType',
#  'l S 250',
#  'S 250',
#  'e S 250',
#  'Sess',
#  'l alf',
#  'alf',
#  'e alf',
#  'u alf',
#  'Rem',
#  'SimbadName',
#  'RA',
#  'DE',
#  'RAJ2000',
#  'DEJ2000',
#  'r',
#  'recno',
#  'Clus',
#  'Name',
#  'Other',
#  'RAB1950',
#  'DEB1950',
#  'z',
#  'Opt',
#  'Ref',
#  'RA.icrs',
#  'DE.icrs',
#  'RAJ2000',
#  'DEJ2000',
#  'r',
#  'recno',
#  'type',
#  'Name',
#  'f Name',
#  'Simbad',
#  'RAJ2000',
#  'DEJ2000',
#  'VarType',
#  'SpType',
#  'Comments',
#  'RAJ2000',
#  ...]

# %%
target_ucd = [ u for ucds in ucd_columns for u in ucds ]
print(len(target_ucd))
# Out:
# 24511

# %% [markdown]
# Now we map the UCDs to numerical values.

# %%
d_ucd2id = { u:i for i,u in enumerate(set(target_ucd)) }
d_id2ucd = { d_ucd2id[u]:u for u in d_ucd2id }
target_id = [ d_ucd2id[u] for u in target_ucd ]
assert len(target_ucd) == len(target_id)

# %% [markdown]
# Scikit-learn provides a set of tools to transform the text data into numerical values, where the values are weighted according to their frequency as well as normalized.
#
# Counting and weighting of terms is important to consider for their relevance, words that are common to many texts get a lower weight as they don't really distinguish as feature within the data. This process is done by the [CountVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) (frequency counter) and [TfidfTransformer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html#sklearn.feature_extraction.text.TfidfTransformer) (weighting).

# %%
## Pipeline
# Naive Bayes

def MNB(features, targets, use_idf=True):
    # Multinomial Naive Bayes
    from sklearn.naive_bayes import MultinomialNB
    from sklearn.feature_extraction.text import TfidfTransformer
    from sklearn.feature_extraction.text import CountVectorizer
    from sklearn.pipeline import Pipeline

    text_clf_nb = Pipeline([('vect', CountVectorizer()),
                        ('tfidf', TfidfTransformer(use_idf=use_idf)),
                        ('clf', MultinomialNB()),
    ])
    text_clf_nb = text_clf_nb.fit(features,targets)
    return text_clf_nb


def CNB(features, targets, use_idf=True):
    # Complement Naive Bayes
    from sklearn.naive_bayes import ComplementNB
    from sklearn.feature_extraction.text import TfidfTransformer
    from sklearn.feature_extraction.text import CountVectorizer
    from sklearn.pipeline import Pipeline

    text_clf_nb = Pipeline([('vect', CountVectorizer()),
                        ('tfidf', TfidfTransformer(use_idf=use_idf)),
                        ('clf', ComplementNB()),
    ])
    text_clf_nb = text_clf_nb.fit(features,targets)
    return text_clf_nb


def best_prediction(classifier):
    return lambda w:d_id2ucd.get(classifier.predict([w])[0])


def top_predictions(classifier):
    def probs(text):
        probs = classifier.predict_proba([text]).flatten()
        indxs = probs.argsort()
        return [(d_id2ucd.get(i),probs[i]) for i in indxs[-3:]][::-1]
    return probs


def print_predict(predicted):
    for u,p in predicted:
        print('{} : {:.5f}'.format(u,p))


def test_evaluate(classifier, features, targets, test_size=0.2):
    from sklearn.model_selection import train_test_split
    import pandas as pd

    assert classifier.lower() in ('mnb','cnb')

    x_train, x_test, y_train, y_test = train_test_split(features, targets, test_size=test_size)
    
    if classifier.lower() == 'mnb':
        text_clf_nb = MNB(x_train,y_train)
    else:
        text_clf_nb = CNB(x_train,y_train)
    
    predicted = [d_id2ucd[i] for i in text_clf_nb.predict(x_test)]
    assert len(predicted)==len(y_test)

    df_eval = pd.DataFrame([(predicted[i],d_id2ucd[y_test[i]]) 
                            for i in range(len(y_test))], 
                           columns=['predicted','truth'])
    return df_eval

# %%
mnb = MNB(names, target_id)
mnb_best_predict = best_prediction(mnb)
mnb_top_predicts = top_predictions(mnb)

# %%
mnb_best_predict('magnitude')
# Out:
# 'stat.error'

# %%
p = mnb_top_predicts('magnitude')
print_predict(p)
# Out:
# stat.error : 0.09947
# phot.flux.density : 0.08074
# POS_EQ_DEC_MAIN : 0.05569

# %%
df_eval = test_evaluate('mnb', names, target_id, 0.2)

sum(df_eval.predicted == df_eval.truth)/len(df_eval)
# Out:
# 0.4199469712420967

# %%
cnb_name = CNB(names, target_id)
cnb_name_best_predict = best_prediction(cnb_name)
cnb_name_top_predicts = top_predictions(cnb_name)

# %%
cnb_name_best_predict('magnitude')
# Out:
# 'POL_PA_MISC'

# %%
p = cnb_name_top_predicts('magnitude')
print_predict(p)
# Out:
# ERROR : 0.00291
# phys.abund.Y : 0.00291
# stat.probability : 0.00291

# %%
df_eval = test_evaluate('cnb', names, target_id, 0.2)

sum(df_eval.predicted == df_eval.truth)/len(df_eval)
# Out:
# 0.4674688965939221

# %% [markdown]
# ## Classifying column descriptions

# %%
desc_columns = read_columns_description(config)
assert len(desc_columns) == len(ucd_columns)

descriptions = [ d for desc in desc_columns for d in desc ]
np.array(descriptions).shape
# Out:
# 171 empty columns
# (24511,)

# %%
mnb_desc = MNB(descriptions, target_id)
mnb_desc_best_predict = best_prediction(mnb_desc)
mnb_desc_top_predicts = top_predictions(mnb_desc)

# %%
mnb_desc_best_predict('magnitude')
# Out:
# 'phot.mag'

# %%
p = mnb_desc_top_predicts('magnitude')
print_predict(p)
# Out:
# phot.mag : 0.36306
# stat.error : 0.12781
# phot.flux.density : 0.12552

# %%
df_eval = test_evaluate('mnb', descriptions, target_id, 0.2)

sum(df_eval.predicted == df_eval.truth)/len(df_eval)
# Out:
# 0.635733224556394

# %%
cnb_desc = CNB(descriptions, target_id)
cnb_desc_best_predict = best_prediction(cnb_desc)
cnb_desc_top_predicts = top_predictions(cnb_desc)

# %%
cnb_desc_best_predict('magnitude')
# Out:
# 'phot.mag'

# %%
p = cnb_desc_top_predicts('magnitude')
print_predict(p)
# Out:
# phot.mag : 0.01285
# phys.magAbs : 0.00305
# None : 0.00292

# %%
df_eval = test_evaluate('cnb', descriptions, target_id, 0.2)

sum(df_eval.predicted == df_eval.truth)/len(df_eval)
# Out:
# 0.7083418315317153

# %%
from sklearn.feature_extraction.text import CountVectorizer
corpus = descriptions
# vectorizer = CountVectorizer(token_pattern='\b[a-zA-Z]\w+\b', analyzer='word', stop_words=None)
vectorizer = CountVectorizer(min_df=0.001)
X = vectorizer.fit_transform(corpus)
print(vectorizer.get_feature_names())
# Out:
# ['00', '00000', '000000', '0000000', '00000000', '000000000000000fk5j2000', '0000000000000fk5j2000', '00000fk5j2000', '0000fk5j2000', '000fk5j2000', '00fk5j2000', '01', '09633760189galactic', '096346019galactic', '10', '11', '11mm', '12', '12co', '13co', '14', '1400mhz', '14ghz', '15', '16', '1950', '19500', '1sigma', '20', '2009', '2011', '20cm', '23', '23ghz', '26200', '262300', '2mass', '408', '423fk4b1950', '42fk4b1950', '48ghz', '50', '57', '5ghz', '610mhz', '6cm', '843mhz', '84ghz', '850um', '86ghz', '9090', 'ab', 'abc', 'absolute', 'accuracy', 'across', 'added', 'al', 'along', 'alpha', 'an', 'and', 'angle', 'angular', 'any', 'aperture', 'apparent', 'arcsec', 'are', 'area', 'as', 'ascension', 'assigned', 'associated', 'association', 'at', 'attenuation', 'available', 'average', 'axis', 'b1950', 'b19500', 'background', 'band', 'based', 'be', 'beam', 'because', 'best', 'beta', 'between', 'bgps', 'brightness', 'by', 'calculated', 'calibration', 'cat', 'catalog', 'catalogue', 'cds', 'center', 'central', 'centre', 'centroid', 'channel', 'circular', 'class', 'classification', 'cloud', 'clump', 'cluster', 'cm', 'co', 'code', 'column', 'comments', 'component', 'components', 'computed', 'confidence', 'continuum', 'coordinates', 'core', 'corrected', 'counterpart', 'cube', 'data', 'database', 'datatypechar', 'datatypeint', 'datatypeshort', 'date', 'de', 'deboosted', 'dec', 'decimal', 'declination', 'deconvolved', 'degree', 'degrees', 'densities', 'density', 'depth', 'derivative', 'derived', 'des', 'designation', 'details', 'detected', 'detection', 'determined', 'deviation', 'diameter', 'difference', 'digits', 'dispersion', 'display', 'dist', 'distance', 'download', 'dust', 'east', 'effective', 'emission', 'empty', 'epoch', 'equinox', 'equinoxj20000', 'error', 'estimate', 'estimated', 'et', 'extended', 'extent', 'extinction', 'factor', 'field', 'file', 'first', 'fit', 'fits', 'fitted', 'fk5', 'flag', 'flux', 'for', 'format', 'fractional', 'frequency', 'from', 'full', 'fwhm', 'g1', 'g2', 'galactic', 'galaxy', 'gaussian', 'ghz', 'given', 'group', 'h2', 'hco', 'heliocentric', 'hhmmddd', 'hi', 'high', 'hii', 'hour', 'hours', 'iau', 'icrs', 'id', 'identification', 'identifier', 'if', 'ii', 'image', 'in', 'include', 'index', 'indicates', 'individual', 'integer', 'integrated', 'intensity', 'internal', 'interval', 'iras', 'is', 'j2000', 'j20000', 'jhhmmddmm', 'jhhmmssddmmss', 'jhhmmsssddmmss', 'jhhmmssssddmmsss', 'jybeam', 'largest', 'latitude', 'level', 'limit', 'line', 'linear', 'link', 'local', 'log', 'logarithm', 'longitude', 'lower', 'lsr', 'luminosity', 'magnetic', 'magnitude', 'major', 'map', 'maps', 'maser', 'mass', 'maximum', 'may', 'mean', 'measure', 'measured', 'median', 'methanol', 'method', 'mhz', 'minimum', 'minor', 'mjd', 'mjy', 'mjybeam', 'model', 'modulation', 'molecular', 'more', 'morphological', 'morphology', 'motion', 'msx', 'multiplicity', 'n2h', 'name', 'names', 'nearest', 'ned', 'new', 'no', 'noise', 'north', 'not', 'note', 'notes', 'notesdat', 'null', 'number', 'nvss', 'object', 'observation', 'observations', 'observed', 'observing', 'of', 'offset', 'on', 'only', 'optical', 'or', 'original', 'other', 'over', 'paco', 'page', 'paper', 'parameter', 'parameters', 'part', 'peak', 'per', 'percentage', 'period', 'photometric', 'photometry', 'pixel', 'pixels', 'planck', 'plot', 'point', 'polarisation', 'polarization', 'polarized', 'position', 'positional', 'positions', 'previous', 'primary', 'probability', 'profile', 'proper', 'pulsar', 'pulse', 'quality', 'ra', 'radial', 'radio', 'radius', 'range', 'ras', 'rate', 'ratio', 'record', 'redshift', 'reference', 'references', 'refsdat', 'region', 'relative', 'requirements', 'resolution', 'resolved', 'rest', 'right', 'rm', 'rms', 'rotation', 'running', 'sample', 'scale', 'sdss', 'second', 'see', 'separation', 'sequential', 'services', 'should', 'show', 'sigma', 'sign', 'signal', 'signaltonoise', 'simbad', 'sio', 'size', 'sky', 'slices', 'source', 'sources', 'sp', 'specfind', 'spect ...

# %%
descriptions
# Out:
# ['Source Designation',
#  'AT20G Identification Murphy et al2010MNRAS4022403M',
#  'Right Ascension',
#  'Declination',
#  'Measured 148GHz Flux Density mJy',
#  'Deboosted 148GHz Flux Density mJy',
#  '',
#  'ACTS Source Designation ACTS JHHMMSSDDMMSS',
#  'Right Ascension',
#  'Declination',
#  'Deboosted Flux Density at 148 GHz',
#  'Negative Error on Deboosted Flux Density at 148 GHz',
#  'Positive Error on Deboosted Flux Density at 148 GHz',
#  'Deboosted Flux Density at 218 GHz',
#  'Negative Error on Deboosted Flux Density at 218 GHz',
#  'Positive Error on Deboosted Flux Density at 218 GHz',
#  '',
#  'Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Error in Right Ascension',
#  'Error in Declination',
#  'Flux Density at 20 cm',
#  'Error in Flux Density at 20 cm',
#  'Integrated Flux Density at 20 cm',
#  'Error in Integrated Flux Density at 20 cm',
#  '',
#  'Sequential Identification Number for Each Radio Source in Catalog',
#  'AEGIS20 Source Identifier',
#  'Integrated 20cm Flux Density',
#  '1Sigma Uncertainty in Integrated 20cm Flux Density',
#  'Counterpart Index Identifier',
#  'EGSIRAC Identifier Barmby et al 2008',
#  'Right Ascension',
#  'Declination',
#  'Redshift',
#  'SpitzerIRAC 36Micron Band AB Magnitude',
#  'Uncertainty in SpitzerIRAC 36Micron Band AB Magnitude',
#  '',
#  'CatalogBased Source Designation',
#  'Right Ascension of Peak',
#  'Declination of Peak',
#  'Peak Flux Density',
#  'Error for Peak Flux Density',
#  'Integrated Flux Density',
#  'Error on integrated Flux Density',
#  'Flag PE Indicates Type of Source',
#  '',
#  'Source Designation AMIGPS JHHMMSSDDMMSS',
#  'Right Ascension Peak',
#  'Declination Peak',
#  'Peak Flux Density at 157 GHz',
#  'Error in Peak Flux Density',
#  'Right Ascension Centroid',
#  'Declination Centroid',
#  'Integrated Flux Density at 157 GHz',
#  'Error in Integrated Flux Density',
#  '',
#  'Source Designation HBM2016 JHHMMSSssDDMMSSss',
#  'Right Ascension',
#  'Right Ascension Error 1Sigma',
#  'Declination',
#  'Declination Error 1Sigma',
#  'Peak Flux Density of the Component at 863MHz',
#  'Peak Flux Density Error',
#  'Integrated Flux Density of the Component at 863MHz',
#  'Integrated Flux Density Error',
#  'RMS Local Noise at the Position of the Component',
#  '',
#  'Source Designation AT20G JHHMMSSDDMMSS or Fornax A',
#  'Right Ascension',
#  'Declination',
#  '18GHz Scalar Average Flux Density',
#  'RMS Uncertainty in 18GHz Scalar Average Flux Density',
#  'Limit Flag for Polarized Flux Density at 18 GHz',
#  'Polarized Flux Density at 18 GHz',
#  'RMS Uncertainty in Polarized Flux Density at 18 GHz',
#  'Flags sfbwc Indicate Notes Concerning Sources',
#  '',
#  'Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Limit Flag for Flux Density at 20 GHz',
#  'Flux Density at 20 GHz mJy',
#  'RMS Uncertainty on Flux Density at 20 GHz mJy',
#  'Alternative Designation PMN PKS NVSS',
#  '',
#  'Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Flux Density at 20 GHz',
#  'Flux Density at 86 GHz',
#  'Flux Density at 48 GHz',
#  'Flux Density at 14 GHz',
#  'First 6km Visibility',
#  'Second 6km Visibility',
#  'Uncertainty in All the 6km Visibilities',
#  '',
#  'IAUStyle Designation of the Radio Source',
#  '2FGL Designation of the GammaRay Source',
#  'Right Ascension',
#  'Declination',
#  'Flux Density at 5 GHz',
#  'Uncertainty in Flux Density at 5 GHz',
#  'Flux Density at 9 GHz',
#  'Uncertainty in Flux Density at 9 GHz',
#  'Distance Between GammaRay and Radio Source',
#  'Distance Between GammaRay and Radio Source Normalized by Its Uncertainty',
#  '',
#  'Source Designation',
#  'Right Ascension',
#  'Declination',
#  'ATATS Flux Density',
#  'Background RMS',
#  'Total NVSS Flux Density',
#  'Major Axis Size',
#  'Minor Axis Size',
#  '',
#  'Sequential Identification Number for Each Source in Catalog',
#  'Source Designation ATCAADFS JHHMMSSDDMMSS',
#  'Flag A Indicates Believed to be Parts of MultiComponent Sources',
#  'Right Ascension',
#  'Declination',
#  'Peak Flux Density at 20 cm',
#  'RMS Uncertainty in Peak Flux Density at 20 cm',
#  'Integrated Flux Density at 20 cm',
#  'RMS Uncertainty in Integrated Flux Density at 20 cm',
#  '',
#  'Source Designation AT20GDP JHHMMSDDMMSS',
#  'Right Ascension',
#  'Declination',
#  'Total Flux Density at 20 GHz',
#  'RMS Uncertainty in Total Flux Density at 20 GHz',
#  'Limit Flag for Best 14GHz Flux Density',
#  'Best 14GHz Flux Density',
#  'Limit Flag for Alpha',
#  'Spectral Index Alpha Between 14 and 20 GHz',
#  'Spectral Class SSteep FFlat IInverted',
#  '',
#  'IAUStyle Source Designation ATESP JHHMMSSDDMMSSA',
#  'Right Ascension',
#  'Declination',
#  'Source Peak Flux 1400MHz',
#  'Source Integrated Flux 1400MHz',
#  'Intrinsic Source Angular Size Major Axis',
#  'Intrinsic Source Angular Size Minor Axis',
#  'Source Position Angle Measured from N through East for the Major Axis',
#  '',
#  'Alternative Source Designation',
#  'Source Designation ATHDFS JHHMMSSsDDMMSS',
#  'Right Ascension',
#  'Declination',
#  '1Sigma Error in Right Ascension',
#  '1Sigma Error in Declination',
#  'Source 14GHz Peak Flux Density',
#  'Source 14GHz Integrated Flux Density',
#  'Detection SignaltoNoise Ratio',
#  '',
#  'Source Designation',
#  'Right Ascension',
#  'Declination',
#  '1Sigma Error in Right Ascension',
#  '1Sigma Error in Declination',
#  'Frequency Band 25 GHz 52 GHz or 87 GHz',
#  'Source Peak Flux Density',
#  'Source Integrated Flux Density',
#  'Flag Indicates Poor Integrated Flux Density',
#  'SignaltoNoise Ratio of the Detection',
#  '',
#  'Source Designation ATHDFS JHHMMSSsDDMMSSA',
#  'Right Ascension',
#  'Declination',
#  'Limit Flag for Source 14GHz Flux Density',
#  'Source 14GHz Flux Density',
#  'Limit Flag for Source 25GHz Flux Density',
#  'Source 25GHz Flux Density',
#  'Limit Flag for Source 52GHz Flux Density',
#  'Source 52GHz Flux Density',
#  'Limit Flag for Source 87GHz Flux Density',
#  'Source 87GHz Flux Density',
#  'Flag Indicates Flat Inverted AGN or GHzPeaked Source GPS',
#  '',
#  'Source Designation ATHDFS JHHMMSSsDDMMSSA',
#  'Right Ascension',
#  'Declination',
#  'CTIO Catalog Identification',
#  'V Band Magnitude in AB System',
#  'RMS Error in V Magnitude',
#  'CTIO Photometric Redshift',
#  'Uncertainty in CTIO Photometric Redshift',
#  '2dF Redshift',
#  'Flag Indicates Quality of Redshift',
#  '',
#  'Source Designation ZMN2012 F NNNCN',
#  'Right Ascension',
#  'Declination',
#  'Integrated Flux Density at 23GHz',
#  'Error in Integrated Flux Density at 23GHz',
#  'Integrated Flux Density at 14GHz in High Resolution Map',
#  'Error in Integrated Flux Density at 14GHz in High Resolution Map',
#  '14GHz Low Resolution Map to 23GHz Spectral Index',
#  'Error in Spectral Index',
#  '',
#  'IAUStyle Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Peak Source Flux Density',
#  'Uncertainty in Peak Source Flux Density',
#  'Integrated Flux Density',
#  'Local Noise Level',
#  '',
#  'Designation for the Radio Component ATCDFS JHHMMSSssDDMMSSs',
#  'Alternative Designation Based on Component Number NAA2006 CNNN',
#  'Right Ascension',
#  'Declination',
#  'RMS Uncertainty in Right Ascension',
#  'RMS Uncertainty in Declination',
#  'Peak Flux Density at 20 cm',
#  'Sextractor RMS Value at Component Position',
#  'Integrated Flux Density at 20 cm',
#  '',
#  'Full Component Designation',
#  'Right Ascension',
#  'Error in Right Ascension',
#  'Declination',
#  'Error in Declination',
#  'Peak Surface Brightness Corrected for Bandwidth Smearing',
#  'Error in Peak Surface Brightness',
#  'Integrated Surface Brightness',
#  'Error in Integrated Surface Brightness',
#  '',
#  'Component Designation ATELAIS JHHMMSSssDDMMSSs',
#  'Alternative Designation Based on Component from Paper MNC2008 CNNNNN',
#  'Right Ascension',
#  'Declination',
#  'Error in Right Ascension',
#  'Error in Declination',
#  'Peak 20cm Flux Density',
#  'Error in Peak 20cm Flux Density',
#  'Integrated 20cm Flux Density',
#  'Error in Integrated 20cm Flux Density',
#  '',
#  'Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Integrated Flux Density',
#  'Source Type Based on high resolution image',
#  'Number of components for complex sources',
#  '',
#  'Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Peak Flux Density Untapered Map',
#  'Integrated Flux Density Untapered Map',
#  'Error on Integrated Flux Density',
#  'FWHM Major Axis of the Source',
#  'Source Position Angle North to East',
#  'Flags for Multiple Component Sources',
#  '',
#  'Pulsar Designation Based on J2000 Coordinates',
#  'Right Ascension',
#  'Declination',
#  'Barycentric Period s',
#  'Barycentric Period Uncertainty s',
#  'First Time Derivative of Barycentric Period ss',
#  'Uncertainty in Period Dot ss',
#  'Dispersion Measure pccm3',
#  'Uncertainty in Dispersion Measure pccm3',
#  '',
#  'IAU Source Designation ATPMN JHHMMSSSDDMMSS',
#  'PMN Source Designation PMN JHHMMDDMMa',
#  'Right Ascension',
#  'Declination',
#  'Flux Density at 86 GHz',
#  'Uncertainty in Flux Density at 86 GHz',
#  'Flux Density at 48 GHz',
#  'Uncertainty in Flux Density at 48 GHz',
#  'Spectral Index',
#  'Uncertainty in Spectral Index',
#  '',
#  'Right ascension FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Declination FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Distance from center 00 00 00000000 00 00000FK5J2000',
#  'Record number assigned by the VizieR team Should Not be used for identification',
#  'Designation of the source datatypechar',
#  'Hour of Right Ascension J2000',
#  'Relative position error in Right Ascension',
#  'Degree of Declination J2000',
#  'Relative position error in Declination',
#  'Circular restoring beam diameter in map used for analysis',
#  'V means low surface brightness extended source VLA position given',
#  'Counterpart is seen in CFHT or HST image',
#  'ID in WSRT catalogue 2000AA361L41G NULL integer written as an empty string',
#  'Peak WSRT flux density at 138GHz 15arcsec resolution',
#  'Integrated WSRT flux density',
#  'WSRT flux densities include two sources with same WSRT ID',
#  'Frequency of the observation',
#  'FWHM Bandpass',
#  'Right ascension FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Declination FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Distance from center 000000000000000FK5J2000',
#  'Record number assigned by the VizieR team Should Not be used for identification datatypeint',
#  '1118 Internal indicator',
#  'Identification code of the program',
#  'Source name as mentioned in the observing program',
#  'Starting date of the Observation 5',
#  'LST Time of the first scan on source',
#  'LST Time of the last scan on source',
#  'Total onsource correlation time',
#  'Program type 1',
#  'Original equinox of position 2 NULL integer written as an empty string',
#  'Velocity of the source 3',
#  'LH LSR or Heliocentric velocity',
#  'Sky Frequency of the 3mm receiver 6 NULL integer written as an empty string',
#  'UL Signal UpperLower band of the 3mm receiver',
#  'Sky Frequency of the 1mm receiver 6 NULL integer written as an empty string',
#  'UL Signal UpperLower band of the 1mm receiver',
#  'HV  HorizontalVertical polarisations 6',
#  'HV  Polarisation of 4GHz continuum 6',
#  'Configuration code of the interferometer',
#  'Detailed configuration 4',
#  'Right Ascension J2000',
#  'Declination J2000',
#  'Right ascension FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Declination FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Distance from center 00 00 0000000000 00 0000000FK5J2000',
#  'Record number assigned by the VizieR team Should Not be used for identification',
#  'Pointing position RA J2000',
#  'Pointing position Dec J2000',
#  'Source name datatypechar',
#  'Antennas potentially present 1',
#  'Data processing block ID',
#  'Block start date 2',
#  'Block end date 2',
#  'Frequency in central channel 3',
#  'Channel width in raw data',
#  'Bandwidth of raw data',
#  'Polarisation products potentially available',
#  'Pixel size in RA direction 4',
#  'Pixel size in Dec direction 4',
#  'Number of visibilities on source',
#  'Source type 5',
#  'Associated source5',
#  'Associated source type 5',
#  'Amplitude calibration source',
#  'Flux density assigned to AMPCAL 6',
#  'Proposal code',
#  'Principle Investigator',
#  'Factors affecting data quality',
#  'Link to MERLIN Archive web page for more details',
#  'File in FITS gzipped format',
#  'Right ascension FK5 EquinoxJ20000 at EpochJ2000 proper motions taken into account',
#  'Declination FK5 EquinoxJ20000 at EpochJ2000 proper motions taken into account',
#  'Distance from center 00 00 000000 00 000FK5J2000',
#  'Record number assigned by the VizieR team Should Not be used for identification',
#  'Running sequence number',
#  'Pulsar name B name if exists otherwise the Jname',
#  'Reference of Name see refsdat file',
#  'Pulsar name based on J2000 coordinates datatypechar',
#  'Reference of PSRJ see refsdat file',
#  'Hour of right ascension J2000',
#  'Mean error on RA',
#  'Reference of right ascension see refsdat file',
#  'Degree of Declination J2000',
#  'Mean error on Declination',
#  'Reference of declination see refsdat file',
#  'Proper motion in the right ascension direction',
#  'Mean error of PMRA',
#  'Reference of pmRA see refsdat file',
#  'Proper motion in declination',
#  'Mean error on PMDE',
#  'Reference of pmDE see refsdat file',
#  'Annual parallax',
#  'Mean error on Plx',
#  'Reference of Plx see refsdat file',
#  'Epoch at which the position is measured Modified Julian Date',
#  'Reference of PosEp see refsdat file',
#  'Galactic longitude Gl',
#  'Galactic latitude Gb',
#  'Right ascension J2000',
#  'Declination J2000',
#  'Barycentric period of the pulsar',
#  'Mean error on P0',
#  'Reference of P0 see refsdat file',
#  'Time derivative of barcycentric period',
#  'Mean error on P1',
#  'Reference of P1 see refsdat file',
#  'Barycentric rotation frequency',
#  'Mean error on F0',
#  'Reference of F0 see refsdat file',
#  'Time derivative of barycentric rotation frequency',
#  'Mean error on F1',
#  'Reference of F1 see refsdat file',
#  'Second time derivative of barycentric rotation frequency',
#  'Mean error on F2',
#  'Reference of F2 see refsdat file',
#  'Third time derivative of barycentric rotation frequency',
#  'Mean error on F3',
#  'Reference of F3 see refsdat file',
#  'Epoch of period or frequency MJD',
#  'Referenc of PEpoch see refsdat file',
#  'Dispersion measure',
#  'Mean error on eDM',
#  'Reference of DM see refsdat file',
#  '1st time derivative of dispersion measure DM1 cm3pcyr',
#  'Mean error on DMdt',
#  'Reference of dDMdt see refsdat file',
#  'Rotation measure',
#  'Mean error on eRM',
#  'Reference of RM see refsdat file',
#  'Width of pulse at 50 of peak 1',
#  'Mean error on W50',
#  'Reference of W50 see refsdat file',
#  'Width of pulse at 10 1',
#  'Mean error on W10',
#  'Reference of W10 see refsdat file',
#  'Timescale for pulse periodfrequency data TCB or TDB',
#  'Reference of Units see refsdat file',
#  'Temporal broadening of pulses at 1GHz due to interestellar scattering',
#  'Mean error on TAUSC',
#  'Reference of TAUSC see refsdat file',
#  'Mean flux density at 400MHz',
#  'Mean error on S400',
#  'Reference of S400 see refsdat file',
#  'Mean flux density at 1400MHz',
#  'Mean error on S1400',
#  'Reference of S1400 see refsdat file',
#  'Mean flux density at 2000MHz',
#  'Mean error on S2000',
#  'Reference of S2000 see refsdat file',
#  'Binary model 2',
#  'Reference of Binary see refsdat file',
#  'Epoch of periastron MJD',
#  'Mean error on T0',
#  'Reference of T0 see refsdat file',
#  'Binary period of pulsar',
#  'Mean error on PB',
#  'Refernce of PB see refsdat file',
#  'Projected semimajor axis of orbit lt s units',
#  'Mean error on A1',
#  'Reference of A1 see refsdat file',
#  'Longitude of periastron',
#  'Mean error on OM',
#  'Reference of OM see refsdat file',
#  'Eccentricity',
#  'Mean error on Ecc',
#  'Reference of Ecc see refsdat file',
#  'Epoch of ascending node MJD ELL1 binary model',
#  'Mean error on TASC',
#  'Reference of TASC see refsdat file',
#  'EccsinOM  ELL1 binary model',
#  'Mean error on EPS1',
#  'Reference of EPS1 see refsdat file',
#  'EcccosOM  ELL1 binary model',
#  'Mean error on EPS2',
#  'Reference of EPS2 see refsdat file',
#  'Minimum companion mass assuming i90deg and neutron star mass is 135Msun Minimum Mass',
#  'Median companion mass assuming i60deg Median Mass',
#  'Companion type see refsdat file 3',
#  'Best estimate of the pulsar distance using the tc93 DMbased distance as default',
#  'Distance based on the tc93 electron density model 4',
#  'Reference of DistDM',
#  'DMsinb',
#  'Distance from the Galactic plane based on Dist',
#  'XDistance in XYZ Galactic coordinate system',
#  'YDistance in XYZ Galactic coordinate system',
#  'Names of other objects associated with the pulsar see refsdat file',
#  'Surveys that detected the pulsar discovery survey first 5',
#  'Date of discovery publication',
#  'Type codes for the pulsar 6',
#  'Reference of Type see refdat file',
#  'Number of glitches observed for the pulsar',
#  'Radio luminosity at 400MHz',
#  'Radio luminosity at 1400MHz',
#  'Spin down age tauP2dPdt',
#  'Surface magnetic flux density in Gauss B32x1019PdPdt12',
#  'Spin down energy loss rate in ergss',
#  'Energy flux at the Sun ergskpc2s',
#  'Total proper motion',
#  'PMTot uncertainty',
#  'Transverse velocity based on Dist',
#  'Period derivative corrected for Shklovskii proper motion effect',
#  'Spin down age from P1i',
#  'Surface magnetic dipole from P1i in Gauss',
#  'Magnetic field at light cylinder in Gauss',
#  'Simbad column added by the CDS',
#  'IAUStyle Source Designation',
#  'Right Ascension',
#  'Declination',
#  'HardBand Count Rate',
#  'HardBand Count Rate Error',
#  'HardBand Flux ergscm2',
#  '',
#  'Source Designation IVR2011 JHHMMSSDDMMSS',
#  'Right Ascension',
#  'Declination',
#  'RMS Uncertainty in Right Ascension 1Sigma',
#  'RMS Uncertainty in Declination 1Sigma',
#  '153MHz Flux Density',
#  'RMS Uncertainty in Flux Density 1Sigma',
#  'Local RMS Image Noise Near Source',
#  'Number of Gaussians Fitted to Source',
#  '',
#  'Object Designation DMR2002 JHHMMSSDDMMSS',
#  'Right Ascension',
#  'Declination',
#  'The 1Sigma Radio Positional Uncertainty arcsec',
#  'Integrated 22cm Flux Density mJy',
#  'Uncertainty in the Integrated 22cm Flux Density mJy',
#  'RMS of the 22cm Flux Density mJy',
#  '',
#  'Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Integrated Stokes I Intensity',
#  'Uncertainty in Integrated Stokes I Intensity',
#  'Average Noise Level',
#  'Deconvolved Major Axis',
#  'Uncertainty in Deconvolved Major Axis',
#  'Deconvolved Minor Axis',
#  'Uncertainty in Deconvolved Major Axis',
#  '',
#  'Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Flux Density at 84 GHz',
#  'Limit Flag for R Magnitude',
#  'R Band magnitude',
#  'Object Classification',
#  'Redshift',
#  '',
#  'Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Peak 14GHz VLBA Flux Density',
#  'Uncertainty in Peak 14GHz VLBA Flux Density',
#  'Integrated 14GHz VLBA Flux Density',
#  'Uncertainty in Integrated 14GHz VLBA Flux Density',
#  'Flag 012 Indicates MultiComponent Classification',
#  '',
#  'Right Ascension',
#  'Declination',
#  'Modified Julian Date of Ephemeris',
#  'Barycentric Frequency Hz',
#  'Error in Frequency',
#  'Period 1nu s',
#  'Period Derivative nudotnu2 s2',
#  '',
#  'Source Designation Using Coordinates of the 48GHz Detection',
#  'Right Ascension',
#  'Declination',
#  'The 84 GHz Flux Density mJy',
#  'Spectral Index between Low Frequency and 84 GHz',
#  'Flag Indicates Morphology Class',
#  '',
#  'Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Flux Density at 14 GHz',
#  'Flux Density at 48 GHz',
#  'Flux Density at 84 GHz',
#  'Flux Density at 30 GHz',
#  'Error in Flux Density at 30 GHz',
#  'Notes on Source Properties',
#  '',
#  'Observation ID',
#  'URL used to access download dataset',
#  'Astronomical object observed if any',
#  'Central right ascension ICRS',
#  'Central declination ICRS',
#  'The OPAL identifier of the observing project',
#  'The date and time of the observation In ISO text format in the UTC timezone',
#  'The name of the source being observed',
#  'Coordinate mode',
#  'Equinox of Coords eg 20000',
#  'Right Ascension',
#  'Declination',
#  'MHz Centre frequency for observation',
#  'Backend used for prcessing the observation',
#  'ID of the receiver',
#  'Mode of observation eg CAL PSR SEARCH',
#  'The name of the file',
#  'The fedora identifier of the data collection to which this observation belongs',
#  'The observation start time in Epoch time',
#  'The type of Observation raw preprocessed thumbnail',
#  'The observation length in milliseconds',
#  'The Collection ID the observation file belongs to',
#  'Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Frequency in MHz',
#  'Limit Flag for Flux Density',
#  'Flux Density in mJy',
#  '',
#  'IAU Designation of the Radio Source',
#  '2FGL Designation of the GammaRay Source 2FGL JHHMMmDDMMc',
#  'Flags ef Indicates Notes Concerning Source',
#  'Right Ascension',
#  'Declination',
#  'Uncertainty in Right Ascension without cosdelta Factor',
#  'Uncertainty in Declination',
#  'Flux Density at 5 GHz',
#  'Uncertainty in Flux Density at 5 GHz',
#  'Spectral Index Between 5 and 97 GHz',
#  'Uncertainty in Spectral Index Between 5 and 97 GHz',
#  '',
#  'FIRST Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Peak Flux Density at 14GHz mJy',
#  'Local Noise Estimate of Source mJy',
#  'Integrated Flux Density at 14GHz mJy',
#  'Probability That Source Is a Sidelobe',
#  'Offset of Nearest 2MASS Source',
#  'K Magnitude of Nearest 2MASS Source',
#  '',
#  'Flag MS Indicates Published TableSample from Which the Entry Originates',
#  'Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Redshift',
#  'NVSS 14GHz Flux Density',
#  'O III Flux',
#  'SDSS DR7 rBand AB Magnitude',
#  'Logarithm of the Radio Luminosity nuLnu',
#  'Logarithm of the Black Hole Mass',
#  '',
#  'SDSS Source Designation SDSS JHHMMSSssDDMMSSs',
#  'Right Ascension',
#  'Declination',
#  'Redshift',
#  'NVSS 14GHz Flux Density',
#  'OIII Flux',
#  'SDSS DR7 r Band AB Magnitude',
#  'Logarithm of the Radio Luminosity',
#  'Logarithm of the Black Hole Mass',
#  '',
#  'Source Designation Based on J2000 Position',
#  'Right Ascension',
#  'Uncertainty in Right Ascension s',
#  'Declination',
#  'Uncertainty in Declination arcsec',
#  '485GHz Peak Flux Density mJy',
#  'Uncertainty in Peak Flux Density mJy',
#  '',
#  'NVSS Source Designation NVSS JHHMMSSDDMMSS',
#  'Right Ascension',
#  'Declination',
#  'The 31GHz Flux Density',
#  'Uncertainty in the 31GHz Flux Density',
#  'The 14GHz NVSS Integrated Flux Density',
#  'Uncertainty in the 14GHz NVSS Integrated Flux Density',
#  'Flag Y Indicates Detection  4Sigma',
#  '',
#  'Catalog Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Maximum Intensity mJybeam where FWHM of the beam is 1258 by 681',
#  'Local RMS of the Image mJybeam where FWHM of the beam is 1258 by 681',
#  'Flux Density at 330MHz mJy',
#  '',
#  'Source Designation GLEAM JHHMMSSDDMMSS',
#  'Right Ascension',
#  'RMS Uncertainty in Right Ascension',
#  'Declination',
#  'RMS Uncertainty in Declination',
#  'Peak Flux in 147154MHz Image',
#  'RMS Uncertainty in Fit for Peak Flux in 147154MHz Image',
#  'Integrated Flux in 147154MHz Image',
#  'RMS Uncertainty in Fit for Integrated Flux in 147154MHz Image',
#  'Local Noise Level in 147154MHz Image',
#  '',
#  'Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Peak Flux Density at 610 MHz',
#  'Integrated Flux Density at 610 MHz',
#  'Error on the Best Determination of the Flux Density',
#  'Angular Size',
#  '',
#  'Source Designation GPB2012 JHHMMSSsDDMMSSs',
#  'Right Ascension',
#  'Declination',
#  'Peak Flux at 150 MHz',
#  'Local Noise at 150 MHz',
#  'Integrated Flux Density at 150 MHz',
#  'RMS Uncertainty in Integrated Flux Density at 150 MHz',
#  '',
#  'Source Designation TGSSADR JHHMMSSSDDMMSS',
#  'Right Ascension',
#  'Uncertainty in Right Ascension 1Sigma',
#  'Declination',
#  'Uncertainty in Declination 1Sigma',
#  'Peak Flux at 150 MHz',
#  'Uncertainty in Peak Flux 1Sigma',
#  'Total Integrated Flux Density at 150 MHz',
#  'Uncertainty in Total Integrated Flux Density 1Sigma',
#  'Local Image Background RMS Noise',
#  '',
#  'IAU Designation of Source GMRTEN1 JHHMMSSsDDMMSS',
#  'Centroid Right Ascension',
#  'Centroid Declination',
#  'Peak Pixel Brightness in mJybeam',
#  'Local RMS Noise in mJybeam',
#  'Integrated Flux at 610MHz',
#  'Error for Integrated Flux',
#  'Source Extractor Flag 0123',
#  '',
#  'IAU Designation of Source GMRTEN1 JHHMMSSsDDMMSS',
#  'Centroid Right Ascension',
#  'Centroid Declination',
#  'Peak Pixel Brightness in mJybeam',
#  'Local RMS Noise in mJybeam',
#  'Integrated Flux at 610MHz',
#  'Error for Integrated Flux',
#  'Source Extractor Flag 0123',
#  '',
#  'Source Designation',
#  'Right Ascension',
#  'Error in Right Ascension',
#  'Declination',
#  'Error in Declination',
#  'Fitted Peak Flux Density at 325 MHz',
#  'Error in Peak Flux Density at 325 MHz',
#  'Integrated Flux Density at 325 MHz',
#  'Error in Integrated Flux Density at 325 MHz',
#  '',
#  'Source Designation SSI2009 JHHMMSSDDMMSS',
#  'Right Ascension',
#  'Declination',
#  'Distance from Pointing Center to the Centroid of the Source in the 150MHz Image',
#  'Total Flux Density at 153 MHz',
#  'Total Flux Density at 244 MHz',
#  'Total Flux Density at 330 MHz',
#  'Total Flux Density at 610 MHz',
#  'Spectral Index from a Linear LeastSquares Fit',
#  '',
#  'Source Designation',
#  'Right Ascension',
#  'Mean Error in Right Ascension',
#  'Declination',
#  'Mean Error in Declination',
#  'Peak Flux Density',
#  'Mean Error in Peak Flux Density',
#  'Major Axis',
#  'Mean Error in Major Axis',
#  '',
#  'Source Designation ISW2010 GMRT JHHMMSSDDMMSS',
#  'Right Ascension',
#  'Declination',
#  'GMRT Flux Density at 150MHz',
#  'WSRT Flux Density at 327MHz',
#  'FIRST Flux Density at 1400MHz VIII71',
#  'Spectral Index from the Fit',
#  '',
#  'IAU Designation of Source GMRTLH JHHMMSSsDDMMSS',
#  'Centroid Right Ascension',
#  'Centroid Declination',
#  'Peak Pixel Brightness in mJybeam',
#  'Local RMS Noise in mJybeam',
#  'Integrated Flux at 610MHz',
#  'Error for Integrated Flux',
#  'Source Extractor Flag 0123',
#  '',
#  'IAU Designation of Source GMRTLH JHHMMSSsDDMMSS',
#  'Centroid Right Ascension',
#  'Centroid Declination',
#  'Peak Pixel Brightness in mJybeam',
#  'Local RMS Noise in mJybeam',
#  'Integrated Flux at 610MHz',
#  'Error for Integrated Flux',
#  'Source Extractor Flag 0123',
#  '',
#  'Source Designation IIB2009 LH610MHz JHHMMSSsDDMMSSa',
#  'Right Ascension',
#  'Declination',
#  'Integrated Flux Density at 610 MHz',
#  'RMS Uncertainty in Integrated Flux Density',
#  'Limit Flag for Spectral Index',
#  'Radio Spectral Index Alpha Between 610MHz and 14GHz',
#  'Upper Uncertainty for Spectral Index',
#  'Lower Uncertainty for Spectral Index',
#  '',
#  'IAU Designation of Source FLSGMRT JHHMMSSsDDMMSS',
#  'Centroid Right Ascension',
#  'Centroid Declination',
#  'Peak Pixel Brightness in mJybeam',
#  'Local RMS Noise in mJybeam',
#  'Integrated Flux at 610MHz',
#  'Error for Integrated Flux',
#  'Source Extractor Flag 01',
#  '',
#  'Source Designation VIRMOS 06GHz JHHMMSSDDMMSSA',
#  'Right Ascension',
#  'Error in Right Ascension',
#  'Declination',
#  'Error in Declination',
#  'Peak Flux Density at 610 MHz in mJybeam',
#  'Error in Peak Flux Density at 610 MHz in mJybeam',
#  'Total Integrated Flux Density at 610 MHz in mJy',
#  'Error in Total Integrated Flux Density at 610 MHz in mJy',
#  'Flag ru Indicates rResolved or uUnresolved',
#  '',
#  'Source Designation TRB2007 JHHMMmDDMMc',
#  'Right Ascension',
#  'RMS Uncertainty in Right Ascension',
#  'Declination',
#  'RMS Uncertainty in Declination',
#  'Integrated Flux Density of Individual Gaussian Fitting Component at 240MHz',
#  'RMS Uncertainty in Int Flux Density of Individual Gaussian Fitting Component',
#  'Limit Flag for Spectral Index',
#  'Spectral Index with Respect to NVSS Flux Density 14GHz',
#  '',
#  'Source Designation TRB2007 JHHMMmDDMMc',
#  'Right Ascension',
#  'RMS Uncertainty in Right Ascension',
#  'Declination',
#  'RMS Uncertainty in Declination',
#  'Integrated Flux Density of Individual Gaussian Fitting Component at 610MHz',
#  'RMS Uncertainty in Int Flux Density of Individual Gaussian Fitting Component',
#  'Limit Flag for Spectral Index',
#  'Spectral Index with Respect to NVSS Flux Density 14GHz',
#  '',
#  'Source Designation',
#  'BeamFitted Right Ascension',
#  'BeamFitted Declination',
#  'BeamFitted Flux Density mJybeam',
#  'Integrated Flux Density mJy',
#  'SignaltoNoise Ratio',
#  'Extent of the Source Size in Units of the Local Beam Area',
#  '',
#  'Source Designation Based on Galactic Position',
#  'Common Alternative Source Designation',
#  'Right Ascension',
#  'Declination',
#  '21cm Peak Flux Density mJy',
#  '36cm Peak Flux Density mJy',
#  '',
#  'Right ascension FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Declination FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Distance from center 00 00 00000000 00 00000FK5J2000',
#  'Record number assigned by the VizieR team Should Not be used for identification',
#  'IAU name of radio source datatypechar',
#  'Other name of radio source',
#  'right ascension hours J2000',
#  'declination sign J2000',
#  'radio source types',
#  'Right ascension FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Declination FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Distance from center 00 00 000000 00 000FK5J2000',
#  'Record number assigned by the VizieR team Should Not be used for identification',
#  'dco flag defining nature of source',
#  'Source Name datatypechar',
#  'Right Ascension hours J2000',
#  'Declination sign J2000',
#  'Name alias of source',
#  'Right ascension FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Declination FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Distance from center 23 57 2623500 16 4227FK4B1950',
#  'Record number assigned by the VizieR team Should Not be used for identification',
#  '13021 Running number',
#  'Main designation datatypechar',
#  'Other name',
#  'D for stars detected',
#  'Right Ascension 1950',
#  'Declination 1950',
#  'Simbad column added by the CDS',
#  'Right ascension ICRS computed by VizieR not part of the original data',
#  'Declination ICRS computed by VizieR not part of the original data',
#  'Sequential Identification Number for Each Source in Catalog',
#  'Object Designation',
#  'Right Ascension',
#  'Declination',
#  'Flag 01 Indicates Spatial Confusion',
#  '1760keV Flux in mCrab',
#  '1760keV 1Sigma Flux Error in mCrab',
#  'Source Type',
#  '',
#  'Target Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Start Time of the Observation in UTC',
#  'Observation Mode',
#  'Short Name of the Receiver Band Used',
#  'Frequency Used for the Observation',
#  '',
#  'Observing Program Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Start Time of the Observation in UTC',
#  'Total OnSource Correlation Time',
#  'Program Type',
#  'Identification Code of the Program',
#  'Name of the Principal Investigator',
#  '',
#  'Observing Program Source Designation',
#  'Right Ascension',
#  'Declination',
#  'Start Time of the Observation in UTC',
#  'Total OnSource Correlation Time',
#  'Program Type',
#  'Name of the Principal Investigator',
#  '',
#  'Right ascension FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Declination FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Distance from center 23 57 26200 16 42FK4B1950',
#  'Record number assigned by the VizieR team Should Not be used for identification datatypeint',
#  'Designation The sources are designated as 18P408 MHz 19P1420MHz and ECX64800 MHz',
#  'Right ascension 1950',
#  'rms uncertainty on right ascension',
#  'Declination 1950',
#  'rms uncertainty on declination NULL integer written as an empty string',
#  'Integrated flux density',
#  'rms uncertainty on flux density If no value is given the published table mentions centroid NULL integer written as an empty string',
#  'Peak flux If no value is given the published table mentions integrated NULL integer written as an empty string',
#  'rms uncertainty on peak flux NULL integer written as an empty string',
#  'Size along major axis',
#  'Size along minor axis',
#  '90180 Position angle NULL integer written as an empty string',
#  'Right ascension ICRS computed by VizieR not part of the original data',
#  'Declination ICRS computed by VizieR not part of the original data',
#  'Right ascension FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Declination FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Distance from center 23 57 262300 16 423FK4B1950',
#  'Record number assigned by the VizieR team Should Not be used for identification',
#  'IRAS designation 1 datatypechar',
#  'Galactic longitude',
#  'Galactic latitude',
#  'Right Ascension 1950 hours of radio source',
#  'Declination 1950 degrees',
#  'Distance between IRAS and radio sources',
#  'Radio continuum 6cm 479GHz flux density',
#  'error estimate on S6cm',
#  'Limit flag on FWHM',
#  'radio gaussian diameter at FWHM',
#  'Limit flag on Diam',
#  'Actual diameter',
#  'Limit flag on Tb',
#  'Brightness temperature',
#  'InfraRed Excess ratio of total farIR flux to the radio flux',
#  'Right ascension FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Declination FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Distance from center 23 57 26200 16 42FK4B1950',
#  'Record number assigned by the VizieR team Should Not be used for identification',
#  'IRAS name',
#  'Right ascension 1950',
#  'Declination 1950',
#  'Galactic longitude lII',
#  'Galactic latitude bII',
#  'IRAS fluxes F12F25F60',
#  'IRAS LRS type 1',
#  'IRAS variability index',
#  'Other object designations',
#  'Right ascension ICRS computed by VizieR not part of the original data',
#  'Declination ICRS computed by VizieR not part of the original data',
#  'Distance from center 000000000000000FK5J2000',
#  'Record number assigned by the VizieR team Should Not be used for identification',
#  'Simbad column added by the CDS',
#  'Star name datatypechar',
#  'MK spectral type table8 only',
#  'Limit flag on S250',
#  'Flux in continuum at 250GHz',
#  'rms uncertainty on S250',
#  'List of session numbers',
#  'Limit flag on spectral index',
#  'Spectral index Snuproptonualf',
#  'rms uncertainty on spectral index',
#  'Uncertainty flag on alf',
#  'Remarks',
#  'Simbad column added by the CDS',
#  'Computed Right Ascension for Equinox J2000',
#  'Computed Declination for Equinox J2000',
#  'Right ascension FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Declination FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Distance from center 23 57 262300 16 423FK4B1950',
#  'Record number assigned by the VizieR team Should Not be used for identification',
#  'Cluster name',
#  'Radio source name',
#  'Other radio galaxy name',
#  'Right ascension B1950',
#  'Declination B1950',
#  'Cluster redshift',
#  'Galaxy optical type',
#  'Reference',
#  'Right ascension ICRS computed by VizieR not part of the original data',
#  'Declination ICRS computed by VizieR not part of the original data',
#  'Right ascension FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Declination FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  'Distance from center 00 00 00000 00 00FK5J2000',
#  'Record number assigned by the VizieR team Should Not be used for identification',
#  'Type of object G1',
#  'Object name datatypechar',
#  'for objects not observed without positions in the original table 2',
#  'ask the SIMBAD database about this object',
#  'Right Ascension J2000 hours from Simbad',
#  'Declination J2000 degrees from Simbad',
#  'Type of variable',
#  'Spectral type',
#  'Comments including other names',
#  'Right ascension FK5 EquinoxJ20000 computed by VizieR not part of the original data The format may include more digits than the original data because of internal accuracy requirements in VizieR and across other CDS services',
#  ...]
